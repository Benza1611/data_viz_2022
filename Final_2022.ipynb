# %% [markdown]
# <a href="https://colab.research.google.com/github/Benza1611/data_viz_2022/blob/main/Final_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # กลุ่ม Final
# ##ชื่อกลุ่ม laughing-hyena
#
# 1.นางสาวเบญญาภา ระภูเขียว  623020527-6
#
# 2.นางสาว ขนิษฐา ภูโสภา  623021042-5
#
# 3.นายวิฆเนศ เกียรติเกษมสุข  623021055-6

# %% [markdown]
# # โจทย์
# ให้นักศึกษาสร้าง Dashboard แสดงรายงานเกี่ยวกับข้อมูลการตรวจโรค(ov) จาก ไฟล์ alldb.csv และ hospital_list.xlsx
# ( ดาวน์โหลดจาก https://drive.google.com/.../1D... )
# โดยข้อมูลหลักจะอยู่ใน ตาราง alldb.csv (ข้อมูลที่สมบูรณ์ที่สามารถนำมาใช้งานได้ต้องมีค่าใน column ต่อไปนี้ดังนี้
#
#  * user เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
#  * RowKey เป็น String
#  * date เป็น YYYY-MM-DD
#  * phone เป็น String
#  * site เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น)
#  * time เป็น hh-mm-ss
#  * urine มีค่า String
#  * ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)
#  * PartitionKey เป็นตัวเลข 5 หลัก (ตัวเลขเท่านั้น))
#
# ไฟล์ alldb.csv และ hospital_list.xlsx สามารถถูกเชื่อมโยงกันโดย site ในไฟล์ alldb.csv คือ hcode ในไฟล์ hospital_list.xlsx
# โดยข้อมูลสำคัญที่ต้องแสดงคือ
#  * จำนวนการตรวจในแต่ละพื้นที่ (จังหวัด-อำเภอ ในไฟล์ hospital_list.xlsx) เทียบกับ จำนวนที่พบโรค (column ov ในไฟล์ alldb.csv)
#  * ช่วงเวลาที่ตรวจ (date ในไฟล์ alldb.csv)
# อื่นๆที่นักศึกษาเห็นว่าเป็นประโยชน์ (phone
#  * (ชนิดโทรศัพท์ที่ใช้บันทึก), title (คำนำหน้าชื่อ), age (อายุ))
#
# (คิดคะแนนตามกลุ่ม final โดยไฟล์ที่ทุกคนในกลุ่มต้องมีคือไฟล์ data pre-processing และ link ไปที่ Dashboard ที่สร้่างโดยเปิดให้สามารถเข้าไปดูและใช้งานได้)
# ส่งไม่เกิน 23.59 วันจันทร์ที่ 11 เมษายน 2565

# %% [markdown]
# #วิธีทำ
# **เรียกใช้ฟังก์ชั่น**

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os           #เพื่อจัดการกับไฟล์ และ ตัว path ที่เราจะนำเข้า
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# #นำเข้าไฟล์

# %%
from google.colab import drive 
drive.mount('/content/drive')  #เชื่อมข้อมูล เพราะเราจะทำการนำเข้าข้อมูล โดยให้ดึงมาจาก google drive ของเรา
path = '/content/drive/My Drive/Final_2022'
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/Final_2022'

# %% [markdown]
# ##ตารางที่ 1

# %%
data1 = pd.read_csv(os.path.join(path,'alldb.csv'))
data1
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# 0      NaN         NaN  NaN               NaN    NaN       NaN
# 1      NaN  2022-02-24  NaN        iPhone10,4  05310  10:50:32
# 2      NaN         NaN  NaN               NaN    NaN       NaN
# 3      NaN  2022-02-23    0        iPhone13,4  05087  09:59:47
# 4      NaN  2022-02-23  NaN        iPhone13,4  05087  09:44:06
# ...    ...         ...  ...               ...    ...       ...
# 40030  NaN         NaN  NaN        iPhone13,4  01234       NaN
# 40031  NaN         NaN    2        iPhone10,5  01234       NaN
# 40032  NaN         NaN    1        iPhone13,4  01234       NaN
# 40033  NaN         NaN  NaN  Samsung SM-A115F  01234       NaN
# 40034  NaN         NaN    1  Samsung SM-A115F  01234       NaN
#
#                  urine  pid            PartitionKey                  title  \
# 0                  NaN  NaN                     NaN  data is not completed
# 1                  NaN  NaN                     NaN  data is not completed
# 2                  NaN  NaN                     NaN  data is not completed
# 3      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# 4      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# ...                ...  ...                     ...                    ...
# 40030              NaN    5     เกษศิรินทร์  ไชยลาภ  data is not completed
# 40031  ปกติ (เหลืองใส)    5  เถลิงเกียรติ เสริฐเลิศ  data is not completed
# 40032  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
# 40033              NaN    1                    เสรี  data is not completed
# 40034  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
#
#                          age
# 0      data is not completed
# 1      data is not completed
# 2      data is not completed
# 3      data is not completed
# 4      data is not completed
# ...                      ...
# 40030  data is not completed
# 40031  data is not completed
# 40032  data is not completed
# 40033  data is not completed
# 40034  data is not completed
#
# [40035 rows x 14 columns]

# %%
data1.shape #ตรวจสอบขนาด
# Out:
# (40035, 14)

# %% [markdown]
# เนื่องจากข้อมูลมีจำนวนมาก แต่เราไม่ได้ใช้ทั้งหมด เพื่อง่ายต่อการทำ prepocessing ดังนั้นจะตัดมาแค่ข้อมูลที่ต้องการใช้จริงๆ ตามโจทย์

# %% [markdown]
# ### ตรวจสอบ NaN และ Missing

# %%
data1.isnull().any()  # ตรวจสอบหาค่า missing
#.isnull() เพื่อระบุว่ามีค่า Null หรือไม่
# Out:
# Unnamed: 0      False
# user             True
# RowKey           True
# care             True
# date             True
# ov               True
# phone            True
# site             True
# time             True
# urine            True
# pid              True
# PartitionKey     True
# title            True
# age              True
# dtype: bool

# %% [markdown]
# จากผลเราจะพิจารณาจากการอ่านค่า True และ False ถ้า True คือ มีค่า missing ดังนั้น จะเห็นได้ว่าข้อมูลมีค่า missing เกือบในทุกคอลัมน์ ดังนั้น สามารถอนุมานได้เลยว่า ข้อมูลมีค่า missing จำนวนมาก จึงไม่เหมาะกับตัดข้อมูล หรือ .dropna
# จึงพิจารณาให้ใช้วิธีแทนค่าเฉพาะคอลัมน์ข้อมูลที่เราต้องการใช้

# %% [markdown]
# # Data Preprocessing

# %%
data = data1[['user','RowKey','date','ov','phone','site','time','urine','PartitionKey','title','age']]
data
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#         ov             phone   site      time            urine  \
# 0      NaN               NaN    NaN       NaN              NaN
# 1      NaN        iPhone10,4  05310  10:50:32              NaN
# 2      NaN               NaN    NaN       NaN              NaN
# 3        0        iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)
# 4      NaN        iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)
# ...    ...               ...    ...       ...              ...
# 40030  NaN        iPhone13,4  01234       NaN              NaN
# 40031    2        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)
# 40032    1        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)
# 40033  NaN  Samsung SM-A115F  01234       NaN              NaN
# 40034    1  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)
#
#                  PartitionKey                  title                    age
# 0                         NaN  data is not completed  data is not completed
# 1                         NaN  data is not completed  data is not completed
# 2                         NaN  data is not completed  data is not completed
# 3                         NaN  data is not completed  data is not completed
# 4                         NaN  data is not completed  data is not completed
# ...                       ...                    ...                    ...
# 40030     เกษศิรินทร์  ไชยลาภ  data is not completed  data is not completed
# 40031  เถลิงเกียรติ เสริฐเลิศ  data is not completed  data is not completed
# 40032                    เสรี  data is not completed  data is not completed
# 40033                    เสรี  data is not completed  data is not completed
# 40034                    เสรี  data is not completed  data is not completed
#
# [40035 rows x 11 columns]

# %%
A=list() 
for each_row in data.iterrows(): # loop each_row ใน data
    if len(str(each_row[1]['user']))== 5 : #เลือกตัวอักษรที่เท่ากับ 5
        if str(each_row[1]['user']) <= '99999' : #ถ้า user  น้อยกว่า 100000
            A.append(True) #ให้เพิ่มเข้าไปใน A
        elif str(each_row[1]['user']) >= '99999' : #ถ้า user มากกว่า 100000
            A.append(False) #ไม่ให้เพิ่มเข้าไปใน A
    else:
        A.append(False) #ถ้าไม่ใช่ทั้งหมด ไม่ให้เพิ่มเข้าไปใน A

data_test = data[A] # ใส่ตัวแปร
data_test# เรียกดูตาราง
# Out:
#         user                                RowKey        date   ov  \
# 1      04857  136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24  NaN
# 5      08777  472EED3E-E2A7-4551-9249-D87747C68AFD  2022-02-25  NaN
# 7      04857  73E96EE6-7660-4204-9914-92112603C514  2022-02-24  NaN
# 11     08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  2022-02-25  NaN
# 12     11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  2022-02-27  NaN
# ...      ...                                   ...         ...  ...
# 39813  99999                        lnlohgqckf.png  2022-03-10    0
# 39814  99999                        vkdocpmjiv.png  2022-03-10    1
# 39815  99999                        vrvyfnvayq.png  2022-03-10    1
# 39816  99999                        zuhbtvyrce.png  2022-03-10    1
# 40017  12345                        zgvicawbkg.png         NaN    2
#
#                   phone   site      time                 urine PartitionKey  \
# 1            iPhone10,4  05310  10:50:32                   NaN          NaN
# 5            iPhone13,2  05248  10:14:46                   NaN          NaN
# 7            iPhone10,4  05310  11:14:21                   NaN          NaN
# 11           iPhone13,2  05248  10:14:32                   NaN          NaN
# 12           iPhone13,3  22222  17:39:35                   NaN          NaN
# ...                 ...    ...       ...                   ...          ...
# 39813  Samsung SM-G998B  99999  18:10:29               มีตะกอน        99999
# 39814  Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง        99999
# 39815  Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)        99999
# 39816  Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)        99999
# 40017  Samsung SM-G998B  xxxxx       NaN       ปกติ (เหลืองใส)        xxxxx
#
#                        title                    age
# 1      data is not completed  data is not completed
# 5      data is not completed  data is not completed
# 7      data is not completed  data is not completed
# 11     data is not completed  data is not completed
# 12     data is not completed  data is not completed
# ...                      ...                    ...
# 
#  '66771',
#  '01883',
#  '66437',
#  '24468',
#  '27604',
#  '19671',
#  '49880',
#  '62687',
#  '89801',
#  '06964',
#  '00148',
#  '89195',
#  '00185',
#  '05116',
#  '28961',
#  '68759',
#  '81197',
#  '51474',
#  '00011',
#  '00207',
#  '11111',
#  '19808',
#  '03338',
#  '14037',
#  '47607',
#  '02518',
#  '00203',
#  '45787',
#  '41026',
#  '00288',
#  '51568',
#  '44812',
#  '46415',
#  '95301',
#  '07166',
#  '21831',
#  '45161',
#  '31208',
#  '69576',
#  '16321',
#  '45752',
#  '94087',
#  '00400',
#  '00079',
#  '00348',
#  '15678',
#  '12015',
#  '70281',
#  '62491',
#  '00126',
#  '37018',
#  '29391',
#  '28627',
#  '43257',
#  '63477',
#  '77670',
#  '00141',
#  '63564',
#  '32948',
#  '99250',
#  '00026',
#  '37645',
#  '22244',
#  '29309',
#  '89251',
#  '08236',
#  '67864',
#  '16604',
#  '75061',
#  '82685',
#  '03535',
#  '00016',
#  '37551',
#  '00578',
#  '02647',
#  '02230',
#  '10264',
#  '65656',
#  '21010',
#  '64671',
#  '62941',
#  '00025',
#  '73375',
#  '00009',
#  '00159',
#  '33869',
#  '64211',
#  '45884',
#  '66205',
#  '16193',
#  '31062',
#  '66082',
#  '73302',
#  '00215',
#  '93527',
#  '25179',
#  '78133',
#  '46783',
#  '37231',
#  '00050',
#  '00187',
#  '87541',
#  '96760',
#  '00168',
#  '88459',
#  '82894',
#  '82277',
#  '55239',
#  '00221',
#  '03831',
#  '29118',
#  '00343',
#  '09902',
#  '00189',
#  '55415',
#  '23231',
#  '65254',
#  '48493',
#  '48440',
#  '00037',
#  '61359',
#  '05433',
#  '62241',
#  '74335',
#  '00201',
#  '85504',
#  '50951',
#  '52830',
#  '73000',
#  '00224',
#  '38822',
#  '22692',
#  '38305',
#  '71781',
#  '14988',
#  ...}

# %%
B=list() 
for each_row in data_test.iterrows(): # loop each_row ใน data_test
    if len(str(each_row[1]['site']))== 5 : #เลือกตัวอักษรที่เท่ากับ 5
        if str(each_row[1]['site']) <= '99999' : #ถ้า user  น้อยกว่า 100000
            B.append(True) #ให้เพิ่มเข้าไปใน B
        elif str(each_row[1]['site']) >= '99999' : #ถ้า user มากกว่า 100000
            B.append(False) #ไม่ให้เพิ่มเข้าไปใน B
    else:
        B.append(False) #ถ้าไม่ใช่ทั้งหมด ไม่ให้เพิ่มเข้าไปใน B

data_test2 = data_test[B] # ใส่ตัวแปร
data_test2# เรียกดูตาราง
# Out:
#         user                                RowKey        date   ov  \
# 1      04857  136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24  NaN
# 5      08777  472EED3E-E2A7-4551-9249-D87747C68AFD  2022-02-25  NaN
# 7      04857  73E96EE6-7660-4204-9914-92112603C514  2022-02-24  NaN
# 11     08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  2022-02-25  NaN
# 12     11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  2022-02-27  NaN
# ...      ...                                   ...         ...  ...
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11    1
# 39813  99999                        lnlohgqckf.png  2022-03-10    0
# 39814  99999                        vkdocpmjiv.png  2022-03-10    1
# 39815  99999                        vrvyfnvayq.png  2022-03-10    1
# 39816  99999                        zuhbtvyrce.png  2022-03-10    1
#
#                   phone   site      time                 urine PartitionKey  \
# 1            iPhone10,4  05310  10:50:32                   NaN          NaN
# 5            iPhone13,2  05248  10:14:46                   NaN          NaN
# 7            iPhone10,4  05310  11:14:21                   NaN          NaN
# 11           iPhone13,2  05248  10:14:32                   NaN          NaN
# 12           iPhone13,3  22222  17:39:35                   NaN          NaN
# ...                 ...    ...       ...                   ...          ...
# 39812        iPhone14,2  99999  11:36:34                  ขุ่น        99999
# 39813  Samsung SM-G998B  99999  18:10:29               มีตะกอน        99999
# 39814  Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง        99999
# 39815  Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)        99999
# 39816  Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)        99999
#
#                        title                    age
# 1      data is not completed  data is not completed
# 5      data is not completed  data is not completed
# 7      data is not completed  data is not completed
# 11     data is not completed  data is not completed
# 12     data is not completed  data is not completed
# ...                      ...                    ...
# 39812                    NaN                    NaN
# 39813                    NaN                    NaN
# 39814                    NaN                    NaN
# 39815                    NaN                    NaN
# 39816                    NaN                    NaN
#
# [38498 rows x 11 columns]

# %%
set(data_test2['site'])
# Out:
# {' 0502',
#  '00004',
#  '00006',
#  '00007',
#  '00008',
#  '00012',
#  '00016',
#  '00017',
#  '00018',
#  '00027',
#  '00028',
#  '00040',
#  '00052',
#  '00055',
#  '00061',
#  '00069',
#  '00070',
#  '00071',
#  '00081',
#  '00082',
#  '00090',
#  '00094',
#  '00096',
#  '00108',
#  '00109',
#  '00115',
#  '00120',
#  '00122',
#  '00127',
#  '00163',
#  '00164',
#  '00165',
#  '00166',
#  '00169',
#  '00170',
#  '00171',
#  '00173',
#  '00174',
#  '00176',
#  '00177',
#  '00178',
#  '00179',
#  '00180',
#  '00182',
#  '00185',
#  '00186',
#  '00187',
#  '00189',
#  '00190',
#  '00191',
#  '00192',
#  '00193',
#  '00194',
#  '00195',
#  '00196',
#  '00197',
#  '00198',
#  '00200',
#  '00202',
#  '00204',
#  '00205',
#  '00206',
#  '00207',
#  '00209',
#  '00213',
#  '00214',
#  '00217',
#  '00218',
#  '00219',
#  '00229',
#  '00232',
#  '00235',
#  '00240',
#  '00247',
#  '00266',
#  '00271',
#  '00279',
#  '00323',
#  '00331',
#  '00333',
#  '00346',
#  '00348',
#  '00381',
#  '00382',
#  '00385',
#  '00387',
#  '00388',
#  '00389',
#  '00390',
#  '00391',
#  '00394',
#  '00397',
#  '00400',
#  '00401',
#  '00404',
#  '00406',
#  '00408',
#  '00410',
#  '00411',
#  '00412',
#  '00413',
#  '00414',
#  '00415',
#  '00512',
#  '00513',
#  '00579',
#  '00580',
#  '00956',
#  '01151',
#  '02038',
#  '02414',
#  '02536',
#  '02759',
#  '03432',
#  '03616',
#  '03626',
#  '04275',
#  '04279',
#  '04280',
#  '04281',
#  '043.1',
#  '04302',
#  '04312',
#  '04313',
#  '04321',
#  '04322',
#  '04326',
#  '04337',
#  '04347',
#  '04348',
#  '04349',
#  '04351',
#  '04352',
#  '04355',
#  '04374',
#  '04376',
#  '04380',
#  '04384',
#  '04387',
#  '04388',
#  '04390',
#  '04391',
#  '04396',
#  '04399',
#  '04401',
#  '04402',
#  '04403',
#  '04404',
#  '04405',
#  '04406',
#  '04407',
#  '04408',
#  '04433',
#  '04434',
#  '04435',
#  '04436',
#  '04437',
#  '04438',
#  '04441',
#  '04443',
#  '04455',
#  '04456',
#  '04457',
#  '04458',
#  '04475',
#  '04478',
#  '04558',
#  '04936',
#  '04968',
#  '04970',
#  '04971',
#  '04973',
#  '04974',
#  '04977',
#  '04980',
#  '04981',
#  '04982',
#  '04983',
#  '04984',
#  '04985',
#  '04986',
#  '04989',
#  '04990',
#  '04992',
#  '04993',
#  '04994',
#  '04995',
#  '04996',
#  '04997',
#  '04999',
#  '05000',
#  '05001',
#  '05002',
#  '05003',
#  '05004',
#  '05005',
#  '05006',
#  '05007',
#  '05008',
#  '05009',
#  '05010',
#  '05011',
#  '05012',
#  '05013',
#  '05015',
#  '05016',
#  '05019',
#  '05021',
#  '05022',
#  '05023',
#  '05024',
#  '05025',
#  '05026',
#  '05027',
#  '05028',
#  '05029',
#  '05032',
#  '05033',
#  '05034',
#  '05035',
#  '05038',
#  '05040',
#  '05042',
#  '05044',
#  '05045',
#  '05047',
#  '05048',
#  '05049',
#  '05052',
#  '05054',
#  '05055',
#  '05058',
#  '05059',
#  '05060',
#  '05061',
#  '05062',
#  '05063',
#  '05064',
#  '05065',
#  '05066',
#  '05067',
#  '05068',
#  '05069',
#  '05072',
#  '05074',
#  '05075',
#  '05077',
#  '05080',
#  '05081',
#  '05082',
#  '05083',
#  '05084',
#  '05086',
#  '05087',
#  '05088',
#  '05090',
#  '05091',
#  '05094',
#  '05097',
#  '05098',
#  '05100',
#  '05101',
#  '05102',
#  '05103',
#  '05107',
#  '05111',
#  '05112',
#  '05113',
#  '05115',
#  '05116',
#  '05117',
#  '05119',
#  '05120',
#  '05123',
#  '05125',
#  '05126',
#  '05128',
#  '05129',
#  '05131',
#  '05132',
#  '05133',
#  '05135',
#  '05136',
#  '05141',
#  '05143',
#  '05144',
#  '05146',
#  '05147',
#  '05152',
#  '05154',
#  '05157',
#  '05158',
#  '05162',
#  '05166',
#  '05172',
#  '05173',
#  '05175',
#  '05177',
#  '05178',
#  '05180',
#  '05181',
#  '05182',
#  '05185',
#  '05187',
#  '05188',
#  '05192',
#  '05193',
#  '05194',
#  '05195',
#  '05196',
#  '05198',
#  '05200',
#  '05203',
#  '05205',
#  '05207',
#  '05210',
#  '05211',
#  '05213',
#  '05214',
#  '05215',
#  '05219',
#  '05220',
#  '05222',
#  '05223',
#  '05224',
#  '05225',
#  '05226',
#  '05228',
#  '05229',
#  '05233',
#  '05236',
#  '05237',
#  '05238',
#  '05240',
#  '05241',
#  '05242',
#  '05244',
#  '05245',
#  '05246',
#  '05247',
#  '05248',
#  '05249',
#  '05250',
#  '05251',
#  '05252',
#  '05253',
#  '05254',
#  '05256',
#  '05257',
#  '05258',
#  '05259',
#  '05260',
#  '05261',
#  '05264',
#  '05265',
#  '05291',
#  '05298',
#  '05300',
#  '05304',
#  '05310',
#  '05311',
#  '05312',
#  '05313',
#  '05314',
#  '05315',
#  '05316',
#  '05322',
#  '05323',
#  '05324',
#  '05325',
#  '05327',
#  '05328',
#  '05332',
#  '05335',
#  '05337',
#  '05338',
#  '05339',
#  '05340',
#  '05343',
#  '05344',
#  '05345',
#  '05346',
#  '05349',
#  '05350',
#  '05351',
#  '05352',
#  '05354',
#  '05355',
#  '05356',
#  '05357',
#  '05358',
#  '05359',
#  '05360',
#  '05361',
#  '05363',
#  '05365',
#  '05366',
#  '05367',
#  '05368',
#  '05369',
#  '05370',
#  '05371',
#  '05373',
#  '05378',
#  '05386',
#  '05391',
#  '05392',
#  '05393',
#  '05394',
#  '05395',
#  '05396',
#  '05399',
#  '05413',
#  '05414',
#  '05415',
#  '05416',
#  '05418',
#  '05419',
#  '05422',
#  '05423',
#  '05424',
#  '05425',
#  '05428',
#  '05431',
#  '05432',
#  '05433',
#  '05434',
#  '05435',
#  '05436',
#  '05437',
#  '05438',
#  '05439',
#  '05440',
#  '05441',
#  '05442',
#  '05541',
#  '06238',
#  '06251',
#  '06253',
#  '06254',
#  '06255',
#  '06256',
#  '06257',
#  '06259',
#  '06260',
#  '06261',
#  '06263',
#  '06265',
#  '06267',
#  '06268',
#  '06270',
#  '06271',
#  '06272',
#  '06273',
#  '06274',
#  '06275',
#  '06276',
#  '06277',
#  '06278',
#  '06279',
#  '06280',
#  '06281',
#  '06282',
#  '06283',
#  '06285',
#  '06286',
#  '06287',
#  '06288',
#  '06289',
#  '06290',
#  '06291',
#  '06292',
#  '06293',
#  '06294',
#  '06295',
#  '06296',
#  '06297',
#  '06298',
#  '06299',
#  '06300',
#  '06301',
#  '06302',
#  '06307',
#  '06308',
#  '06309',
#  '06310',
#  '06311',
#  '06312',
#  '06314',
#  '06315',
#  '06316',
#  '06318',
#  '06319',
#  '06320',
#  '06321',
#  '06322',
#  '06323',
#  '06324',
#  '06325',
#  '06326',
#  '06327',
#  '06328',
#  '06329',
#  '06330',
#  '06331',
#  '06332',
#  '06333',
#  '06334',
#  '06521',
#  '08485',
#  '10360',
#  '10673',
#  '11010',
#  '11055',
#  '11056',
#  '11057',
#  '11059',
#  '11060',
#  '11066',
#  '11069',
#  '11070',
#  '11072',
#  '11073',
#  '11084',
#  '11088',
#  '11111',
#  '11158',
#  '11159',
#  '11160',
#  '11161',
#  '11163',
#  '11164',
#  '11165',
#  '11740',
#  '11748',
#  '11749',
#  '11800',
#  '11887',
#  '13377',
#  '13777',
#  '13937',
#  '13941',
#  '13943',
#  '13944',
#  '13946',
#  '13947',
#  '13948',
#  '13949',
#  '13952',
#  '13953',
#  '13954',
#  '13955',
#  '13962',
#  '13963',
#  '13966',
#  '13984',
#  '13987',
#  '14005',
#  '14007',
#  '14280',
#  '14284',
#  '14843',
#  '20510',
#  '22222',
#  '24622',
#  '24650',
#  '27988',
#  '27990',
#  '27998',
#  '28017',
#  '28691',
#  '28789',
#  '44902',
#  '45972',
#  '49741',
#  '50210',
#  '75757',
#  '97255',
#  '99795',
#  '99999'}

# %%
data_test2 = data_test2[data_test2['site']!= ' 0502']

# %%
data_test2 = data_test2[(data_test2['PartitionKey'].astype(str).str.isdigit()) & (data_test2['PartitionKey'].str.len() == 5)]      # เลือกมาเฉพาะ คอลัมน์ PartitionKey ที่เป็นตัวเลข & มีตัวเลข เท่ากับ 5 ตัว
print(data_test2.shape)                                                                            
data_test2
# Out:
# (38385, 11)
#         user                                RowKey        date ov  \
# 190    06223                        kfpwuaqldj.png  2022-03-23  0
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30  3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29  3
# ...      ...                                   ...         ... ..
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11  1
# 39813  99999                        lnlohgqckf.png  2022-03-10  0
# 39814  99999                        vkdocpmjiv.png  2022-03-10  1
# 39815  99999                        vrvyfnvayq.png  2022-03-10  1
# 39816  99999                        zuhbtvyrce.png  2022-03-10  1
#
#                    phone   site      time                 urine PartitionKey  \
# 190    Xiaomi 21081111RG  13777  16:31:45       ปกติ (เหลืองใส)        00000
# 191           iPhone12,3  06307  14:46:08       ปกติ (เหลืองใส)        00001
# 192           iPhone14,3  05328  15:27:45       ปกติ (เหลืองใส)        00001
# 193           iPhone13,4  06302  10:16:46       ปกติ (เหลืองใส)        00001
# 194            iPhone9,4  05059  12:26:38       ปกติ (เหลืองใส)        00001
# ...                  ...    ...       ...                   ...          ...
# 39812         iPhone14,2  99999  11:36:34                  ขุ่น        99999
# 39813   Samsung SM-G998B  99999  18:10:29               มีตะกอน        99999
# 39814   Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง        99999
# 39815   Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)        99999
# 39816   Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)        99999
#
#         title  age
# 190       NaN  NaN
# 191    นางสาว   47
# 192       นาง   41
# 193       นาง   55
# 194       นาย   66
# ...       ...  ...
# 39812     NaN  NaN
# 39813     NaN  NaN
# 39814     NaN  NaN
# 39815     NaN  NaN
# 39816     NaN  NaN
#
# [38385 rows x 11 columns]

# %%
set(data_test2['PartitionKey'])
# Out:
# {'04785',
#  '00539',
#  '03071',
#  '01477',
#  '05092',
#  '00517',
#  '00809',
#  '01012',
#  '02158',
#  '06726',
#  '00868',
#  '01425',
#  '02905',
#  '01590',
#  '03155',
#  '00105',
#  '03215',
#  '00543',
#  '01144',
#  '03936',
#  '00036',
#  '00274',
#  '04024',
#  '00394',
#  '00960',
#  '00137',
#  '02677',
#  '44147',
#  '00334',
#  '01548',
#  '00646',
#  '02037',
#  '02040',
#  '03394',
#  '06007',
#  '08959',
#  '01546',
#  '01979',
#  '01301',
#  '03378',
#  '01815',
#  '01240',
#  '01667',
#  '06717',
#  '03107',
#  '00639',
#  '11007',
#  '01965',
#  '01442',
#  '02208',
#  '00351',
#  '01713',
#  '01172',
#  '03981',
#  '01253',
#  '00668',
#  '01422',
#  '04679',
#  '02439',
#  '02997',
#  '00553',
#  '01233',
#  '00438',
#  '01549',
#  '02508',
#  '00455',
#  '00313',
#  '00691',
#  '00281',
#  '00672',
#  '01807',
#  '00620',
#  '03515',
#  '00381',
#  '00082',
#  '03061',
#  '00228',
#  '00425',
#  '00746',
#  '02849',
#  '00337',
#  '00625',
#  '05339',
#  '01909',
#  '05995',
#  '06019',
#  '09039',
#  '02999',
#  '87720',
#  '00790',
#  '01217',
#  '01825',
#  '00764',
#  '00460',
#  '05112',
#  '08989',
#  '00045',
#  '03399',
#  '00657',
#  '02383',
#  '00968',
#  '00382',
#  '01338',
#  '00892',
#  '01035',
#  '02292',
#  '02249',
#  '01511',
#  '00959',
#  '02000',
#  '00211',
#  '02922',
#  '03139',
#  '00844',
#  '02915',
#  '00601',
#  '00452',
#  '00662',
#  '01028',
#  '04683',
#  '01668',
#  '03384',
#  '01645',
#  '00024',
#  '01272',
#  '06059',
#  '01453',
#  '00181',
#  '00433',
#  '01808',
#  '02822',
#  '03419',
#  '00080',
#  '00791',
#  '00914',
#  '02781',
#  '01357',
#  '01856',
#  '01860',
#  '03238',
#  '05195',
#  '00857',
#  '00699',
#  '01389',
#  '00632',
#  '00833',
#  '02537',
#  '00838',
#  '01938',
#  '02652',
#  '02832',
#  '01158',
#  '03234',
#  '03044',
#  '03403',
#  '00102',
#  '01746',
#  '02122',
#  '02355',
#  '05118',
#  '01324',
#  '00407',
#  '03434',
#  '00710',
#  '02348',
#  '04118',
#  '04675',
#  '01818',
#  '05099',
#  '01572',
#  '00535',
#  '04607',
#  '04020',
#  '02404',
#  '02976',
#  '00864',
#  '01325',
#  '08351',
#  '00160',
#  '00577',
#  '02454',
#  '01106',
#  '01465',
#  '01831',
#  '00403',
#  '00834',
#  '10964',
#  '01483',
#  '05209',
#  '05831',
#  '00770',
#  '08926',
#  '03804',
#  '03109',
#  '05117',
#  '00660',
#  '00850',
#  '01097',
#  '02013',
#  '02826',
#  '09044',
#  '01205',
#  '00900',
#  '00219',
#  '02967',
#  '02972',
#  '00982',
#  '01851',
#  '02678',
#  '01055',
#  '01734',
#  '02250',
#  '02685',
#  '01250',
#  '01412',
#  '01617',
#  '03326',
#  '01004',
#  '01843',
#  '00167',
#  '02690',
#  '02233',
#  '01084',
#  '01198',
#  '01458',
#  '01517',
#  '02396',
#  '04625',
#  '05316',
#  '04189',
#  '02320',
#  '01394',
#  '04620',
#  '02857',
#  '00504',
#  '00054',
#  '10974',
#  '00152',
#  '02484',
#  '03182',
#  '00826',
#  '03231',
#  '00686',
#  '08903',
#  '00282',
#  '03424',
#  '01626',
#  '01805',
#  '00727',
#  '01998',
#  '01149',
#  '01199',
#  '02680',
#  '05975',
#  '01605',
#  '08966',
#  '00084',
#  '02743',
#  '01872',
#  '02992',
#  '03263',
#  '03136',
#  '00263',
#  '03092',
#  '00988',
#  '02578',
#  '01729',
#  '00556',
#  '00273',
#  '05981',
#  '00266',
#  '00035',
#  '01801',
#  '00516',
#  '01977',
#  '01659',
#  '05219',
#  '88432',
#  '01100',
#  '02539',
#  '08947',
#  '00778',
#  '01088',
#  '02616',
#  '01838',
#  '01901',
#  '02588',
#  '02401',
#  '01134',
#  '02601',
#  '02440',
#  '01571',
#  '03064',
#  '01168',
#  '00725',
#  '03529',
#  '01833',
#  '00057',
#  '00128',
#  '02144',
#  '00155',
#  '00349',
#  '05354',
#  '04127',
#  '00598',
#  '01326',
#  '01762',
#  '02986',
#  '08905',
#  '00411',
#  '10969',
#  '00650',
#  '00700',
#  '01575',
#  '00280',
#  '00484',
#  '00758',
#  '02873',
#  '03438',
#  '03461',
#  '06008',
#  '01424',
#  '00502',
#  '01692',
#  '06145',
#  '01619',
#  '02878',
#  '01249',
#  '03132',
#  '05716',
#  '02027',
#  '01243',
#  '00957',
#  '00729',
#  '01086',
#  '03093',
#  '08904',
#  '01656',
#  '02461',
#  '00744',
#  '00444',
#  ...}

# %%
data_test2.isnull().any()
# Out:
# user            False
# RowKey          False
# date             True
# ov               True
# phone           False
# site            False
# time             True
# urine            True
# PartitionKey    False
# title            True
# age              True
# dtype: bool

# %%
data_test2
# Out:
#         user                                RowKey        date ov  \
# 190    06223                        kfpwuaqldj.png  2022-03-23  0
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30  3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29  3
# ...      ...                                   ...         ... ..
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11  1
# 39813  99999                        lnlohgqckf.png  2022-03-10  0
# 39814  99999                        vkdocpmjiv.png  2022-03-10  1
# 39815  99999                        vrvyfnvayq.png  2022-03-10  1
# 39816  99999                        zuhbtvyrce.png  2022-03-10  1
#
#                    phone   site      time                 urine PartitionKey  \
# 190    Xiaomi 21081111RG  13777  16:31:45       ปกติ (เหลืองใส)        00000
# 191           iPhone12,3  06307  14:46:08       ปกติ (เหลืองใส)        00001
# 192           iPhone14,3  05328  15:27:45       ปกติ (เหลืองใส)        00001
# 193           iPhone13,4  06302  10:16:46       ปกติ (เหลืองใส)        00001
# 194            iPhone9,4  05059  12:26:38       ปกติ (เหลืองใส)        00001
# ...                  ...    ...       ...                   ...          ...
# 39812         iPhone14,2  99999  11:36:34                  ขุ่น        99999
# 39813   Samsung SM-G998B  99999  18:10:29               มีตะกอน        99999
# 39814   Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง        99999
# 39815   Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)        99999
# 39816   Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)        99999
#
#         title  age
# 190       NaN  NaN
# 191    นางสาว   47
# 192       นาง   41
# 193       นาง   55
# 194       นาย   66
# ...       ...  ...
# 39812     NaN  NaN
# 39813     NaN  NaN
# 39814     NaN  NaN
# 39815     NaN  NaN
# 39816     NaN  NaN
#
# [38385 rows x 11 columns]

# %% [markdown]
# ## แทนค่าข้อมูลที่ผิดปกติ

# %%
data_test2[['ov']] = data_test2[['ov']].fillna('0') ##แทนค่า NaN  เป็น 0
data_test2[['time']] = data_test2[['time']].fillna('ไม่ระบุ') ##แทนค่า NaN  เป็น ไม่ระบุ
data_test2[['urine']] = data_test2[['urine']].fillna('ไม่ระบุ') ##แทนค่า NaN  เป็น ไม่ระบุ
data_test2[['title']] = data_test2[['title']].fillna('ไม่ระบุ') ##แทนค่า NaN  เป็น ไม่ระบุ
data_test2[['age']] = data_test2[['age']].fillna('ไม่ระบุ') ##แทนค่า NaN  เป็น ไม่ระบุ

# %%
data_test2 = data_test2.dropna()

# %%
data_test2
# Out:
#         user                                RowKey        date ov  \
# 190    06223                        kfpwuaqldj.png  2022-03-23  0
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30  4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30  4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30  3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29  3
# ...      ...                                   ...         ... ..
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11  1
# 39813  99999                        lnlohgqckf.png  2022-03-10  0
# 39814  99999                        vkdocpmjiv.png  2022-03-10  1
# 39815  99999                        vrvyfnvayq.png  2022-03-10  1
# 39816  99999                        zuhbtvyrce.png  2022-03-10  1
#
#                    phone   site      time                 urine PartitionKey  \
# 190    Xiaomi 21081111RG  13777  16:31:45       ปกติ (เหลืองใส)        00000
# 191           iPhone12,3  06307  14:46:08       ปกติ (เหลืองใส)        00001
# 192           iPhone14,3  05328  15:27:45       ปกติ (เหลืองใส)        00001
# 193           iPhone13,4  06302  10:16:46       ปกติ (เหลืองใส)        00001
# 194            iPhone9,4  05059  12:26:38       ปกติ (เหลืองใส)        00001
# ...                  ...    ...       ...                   ...          ...
# 39812         iPhone14,2  99999  11:36:34                  ขุ่น        99999
# 39813   Samsung SM-G998B  99999  18:10:29               มีตะกอน        99999
# 39814   Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง        99999
# 39815   Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)        99999
# 39816   Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)        99999
#
#          title      age
# 190    ไม่ระบุ  ไม่ระบุ
# 191     นางสาว       47
# 192        นาง       41
# 193        นาง       55
# 194        นาย       66
# ...        ...      ...
# 39812  ไม่ระบุ  ไม่ระบุ
# 39813  ไม่ระบุ  ไม่ระบุ
# 39814  ไม่ระบุ  ไม่ระบุ
# 39815  ไม่ระบุ  ไม่ระบุ
# 39816  ไม่ระบุ  ไม่ระบุ
#
# [38103 rows x 11 columns]

# %%
data_test2.isnull().any()
# Out:
# user            False
# RowKey          False
# date            False
# ov              False
# phone           False
# site            False
# time            False
# urine           False
# PartitionKey    False
# title           False
# age             False
# dtype: bool

# %% [markdown]
# ## เปลี่ยน type ข้อมูลเป็น String

# %%
import numpy as np

# %% [markdown]
# ### เปลี่ยน user, site, ov, PartitionKey, age เป็นตัวเลขเท่านั้น (int)

# %% [markdown]
# โดยการตั้งค่า  error='coerce' จะแปลงค่าที่ไม่ใช่ตัวเลขเป็น  NaN

# %%
data_test2['user'] = pd.to_numeric(data_test2['user'], errors='coerce')
data_test2['ov'] = pd.to_numeric(data_test2['ov'], errors='coerce')
data_test2['age'] = pd.to_numeric(data_test2['age'], errors='coerce');
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data_test2.dtypes #เช็คไทป์ของข้อมูล
# Out:
# user            float64
# RowKey           object
# date             object
# ov              float64
# phone            object
# site             object
# time             object
# urine            object
# PartitionKey     object
# title            object
# age             float64
# dtype: object

# %% [markdown]
# ตอนนี้จะสังเกตเห็น ค่า NaNโดยที่ประเภทข้อมูลเป็น float
#
# สามารถทำโดยแทนที่ค่า 'NaN' ด้วยค่า '0' โดยใช้ df.replace:

# %%
data_test2 = data_test2.replace(np.nan, 0, regex=True)
data_test2['user'] = data_test2['user'].astype(int)
data_test2['ov'] = data_test2['ov'].astype(int)
data_test2['age'] = data_test2['age'].astype(int)

# %%
data_test2.dtypes #เช็คไทป์ของข้อมูล
# Out:
# user             int64
# RowKey          object
# date            object
# ov               int64
# phone           object
# site            object
# time            object
# urine           object
# PartitionKey    object
# title           object
# age              int64
# dtype: object

# %% [markdown]
# >เปลี่ยน Rowkey phone เเละ urine เป็น String

# %% [markdown]
# ### เปลี่ยน RowKey, phone, urine, title เป็น String

# %%
data_test2 = data_test2.astype({'RowKey':'string', 'phone':'string','urine':'string','title':'string'})
data_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38103 entries, 190 to 39816
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user          38103 non-null  int64
#  1   RowKey        38103 non-null  string
#  2   date          38103 non-null  object
#  3   ov            38103 non-null  int64
#  4   phone         38103 non-null  string
#  5   site          38103 non-null  object
#  6   time          38103 non-null  object
#  7   urine         38103 non-null  string
#  8   PartitionKey  38103 non-null  object
#  9   title         38103 non-null  string
#  10  age           38103 non-null  int64
# dtypes: int64(3), object(4), string(4)
# memory usage: 3.5+ MB

# %%
data_test2
# Out:
#         user                                RowKey        date  ov  \
# 190     6223                        kfpwuaqldj.png  2022-03-23   0
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# ...      ...                                   ...         ...  ..
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11   1
# 39813  99999                        lnlohgqckf.png  2022-03-10   0
# 39814  99999                        vkdocpmjiv.png  2022-03-10   1
# 39815  99999                        vrvyfnvayq.png  2022-03-10   1
# 39816  99999                        zuhbtvyrce.png  2022-03-10   1
#
#                    phone   site      time                 urine PartitionKey  \
# 190    Xiaomi 21081111RG  13777  16:31:45       ปกติ (เหลืองใส)        00000
# 191           iPhone12,3  06307  14:46:08       ปกติ (เหลืองใส)        00001
# 192           iPhone14,3  05328  15:27:45       ปกติ (เหลืองใส)        00001
# 193           iPhone13,4  06302  10:16:46       ปกติ (เหลืองใส)        00001
# 194            iPhone9,4  05059  12:26:38       ปกติ (เหลืองใส)        00001
# ...                  ...    ...       ...                   ...          ...
# 39812         iPhone14,2  99999  11:36:34                  ขุ่น        99999
# 39813   Samsung SM-G998B  99999  18:10:29               มีตะกอน        99999
# 39814   Samsung SM-G998B  99999  12:14:41  ขุ่น, มีเม็ดเลือดแดง        99999
# 39815   Samsung SM-G998B  99999  13:58:01       ปกติ (เหลืองใส)        99999
# 39816   Samsung SM-G998B  99999  13:57:58       ปกติ (เหลืองใส)        99999
#
#          title  age
# 190    ไม่ระบุ    0
# 191     นางสาว   47
# 192        นาง   41
# 193        นาง   55
# 194        นาย   66
# ...        ...  ...
# 39812  ไม่ระบุ    0
# 39813  ไม่ระบุ    0
# 39814  ไม่ระบุ    0
# 39815  ไม่ระบุ    0
# 39816  ไม่ระบุ    0
#
# [38103 rows x 11 columns]

# %% [markdown]
# > กำหนด ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ)

# %%
set(data_test2['ov'])
# Out:
# {0, 1, 2, 3, 4}

# %% [markdown]
# จะเห็นว่า ov เป็นตัวเลข มีค่าตั้งแต่ 0-4 (0 คือไม่พบโรค 1-4 คือพบโรคที่ระดับความรุนแรงต่างๆ) อยู่แล้ว ดังนั้นไม่ต้องแก้ไขอะไร

# %% [markdown]
# >กำหนดรูปแบบของ time เป็น hh-mm-ss

# %%
data_test2['time'] = data_test2['time'].replace(':','-',regex=True)

# %%
data_test2
# Out:
#         user                                RowKey        date  ov  \
# 190     6223                        kfpwuaqldj.png  2022-03-23   0
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889  2022-03-29   3
# ...      ...                                   ...         ...  ..
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  2022-03-11   1
# 39813  99999                        lnlohgqckf.png  2022-03-10   0
# 39814  99999                        vkdocpmjiv.png  2022-03-10   1
# 39815  99999                        vrvyfnvayq.png  2022-03-10   1
# 39816  99999                        zuhbtvyrce.png  2022-03-10   1
#
#                    phone   site      time                 urine PartitionKey  \
# 190    Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)        00000
# 191           iPhone12,3  06307  14-46-08       ปกติ (เหลืองใส)        00001
# 192           iPhone14,3  05328  15-27-45       ปกติ (เหลืองใส)        00001
# 193           iPhone13,4  06302  10-16-46       ปกติ (เหลืองใส)        00001
# 194            iPhone9,4  05059  12-26-38       ปกติ (เหลืองใส)        00001
# ...                  ...    ...       ...                   ...          ...
# 39812         iPhone14,2  99999  11-36-34                  ขุ่น        99999
# 39813   Samsung SM-G998B  99999  18-10-29               มีตะกอน        99999
# 39814   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง        99999
# 39815   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)        99999
# 39816   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)        99999
#
#          title  age
# 190    ไม่ระบุ    0
# 191     นางสาว   47
# 192        นาง   41
# 193        นาง   55
# 194        นาย   66
# ...        ...  ...
# 39812  ไม่ระบุ    0
# 39813  ไม่ระบุ    0
# 39814  ไม่ระบุ    0
# 39815  ไม่ระบุ    0
# 39816  ไม่ระบุ    0
#
# [38103 rows x 11 columns]

# %%
data_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38103 entries, 190 to 39816
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user          38103 non-null  int64
#  1   RowKey        38103 non-null  string
#  2   date          38103 non-null  object
#  3   ov            38103 non-null  int64
#  4   phone         38103 non-null  string
#  5   site          38103 non-null  object
#  6   time          38103 non-null  object
#  7   urine         38103 non-null  string
#  8   PartitionKey  38103 non-null  object
#  9   title         38103 non-null  string
#  10  age           38103 non-null  int64
# dtypes: int64(3), object(4), string(4)
# memory usage: 3.5+ MB

# %%
data_test2['date'] = pd.to_datetime(data_test2['date'], format = "%Y/%m/%d")

# %%
data_test2['time'] = data_test2['time'].replace(':','-', regex=True)
data_test2['time'] = pd.to_datetime(data_test2['time'],format='%H-%M%-%S',errors='ignore')

# %%
data_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38103 entries, 190 to 39816
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user          38103 non-null  int64
#  1   RowKey        38103 non-null  string
#  2   date          38103 non-null  datetime64[ns]
#  3   ov            38103 non-null  int64
#  4   phone         38103 non-null  string
#  5   site          38103 non-null  object
#  6   time          38103 non-null  object
#  7   urine         38103 non-null  string
#  8   PartitionKey  38103 non-null  object
#  9   title         38103 non-null  string
#  10  age           38103 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(3), string(4)
# memory usage: 3.5+ MB

# %% [markdown]
# > เปลี่ยนคอลัมน์ title เป็นเพศ

# %%
set(data_test2['title'])   # ดู set ของข้อมูล
# Out:
# {'  นาง',
#  ' นาง',
#  ' นางสาว',
#  ' นาย',
#  'Mrs',
#  'ชาย',
#  'ด.ช.',
#  'ด.ญ.',
#  'ด.ต.',
#  'น',
#  'น.ส',
#  'น.ส ',
#  'น.ส.',
#  'นส',
#  'นส.',
#  'นส. ',
#  'นาง',
#  'นาง ',
#  'นาง.',
#  'นางl',
#  'นางสาว',
#  'นางสาว ',
#  'นางสาว                   ',
#  'นาน',
#  'นาบ',
#  'นาย',
#  'นาย ',
#  'นาย  ',
#  'นาว',
#  'นาวสาว',
#  'นา่ง',
#  'น่าย',
#  'พจอ.',
#  'พระ',
#  'พระครุ',
#  'พระปลัด',
#  'พลฯ',
#  'ร.ต.',
#  'ร.ต.ต.',
#  'ร.ต.ท.',
#  'ร.ต.อ.',
#  'ว่าที่ ร.ต.',
#  'ว่าที่ ร.ท.',
#  'ว่าที่ร้อยตรี',
#  'ส.อ.',
#  'ืนาง',
#  'เด็กชาย',
#  'เด็กหญิง',
#  'ไม่ระบุ'}

# %%
data_test2['title'].replace({'  นาง':'หญิง',
                    ' นาง':'หญิง',
                    ' นางสาว':'หญิง',
                    ' นาย':'ชาย',
                    'Mrs':'หญิง',
                    'ชาย':'ชาย',
                    'ด.ช.':'ชาย',
                    'ด.ญ.':'หญิง',
                    'ด.ต.':'ไม่ระบุ',
                    'น':'ไม่ระบุ',
                    'น.ส':'หญิง',
                    'น.ส ':'หญิง',
                    'น.ส.':'หญิง',
                    'นส':'หญิง',
                    'นส.':'หญิง',
                    'นส. ':'หญิง',
                    'นาง':'หญิง',
                    'นาง ':'หญิง',
                    'นาง.':'หญิง',
                    'นางl':'หญิง',
                    'นางสาว':'หญิง',
                    'นางสาว ':'หญิง',
                    'นางสาว                   ':'หญิง',
                    'นาน':'ชาย',
                    'นาบ':'ชาย',
                    'นาย':'ชาย',
                    'นาย ':'ชาย',
                    'นาย  ':'ชาย',
                    'นาว':'หญิง',
                    'นาวสาว':'หญิง',
                    'นา่ง':'หญิง',
                    'น่าย':'ชาย',
                    'พจอ.':'ไม่ระบุ',
                    'พระ':'ชาย',
                    'พระครุ':'ไม่ระบุ',
                    'พระปลัด':'ไม่ระบุ',
                    'พลฯ':'ไม่ระบุ',
                    'ร.ต.':'ไม่ระบุ',
                    'ร.ต.ต.':'ไม่ระบุ',
                    'ร.ต.ท.':'ไม่ระบุ',
                    'ร.ต.อ.':'ไม่ระบุ',
                    'รต.':'ไม่ระบุ',
                    'ว่าที่ ร.ต.':'ไม่ระบุ',
                    'ว่าที่ ร.ท.':'ไม่ระบุ',
                    'ว่าที่ร้อยตรี':'ไม่ระบุ',
                    0:'ไม่ระบุ',
                    'data is not completed':'ไม่ระบุ',
                    'okp':'ไม่ระบุ',
                    'ส.อ.':'ไม่ระบุ',
                    'ืนาง':'หญิง',
                    'เด็กชาย':'ชาย',
                    'เด็กหญิง':'หญิง'},inplace=True)

# %%
set(data_test2['title'])
# Out:
# {'ชาย', 'หญิง', 'ไม่ระบุ'}

# %%
data_re = data_test2.rename(columns={'title':'sex'}) #เปลี่ยนชื่อคอลัมน์
data_re.head(5)
# Out:
#       user                                RowKey       date  ov  \
# 190   6223                        kfpwuaqldj.png 2022-03-23   0
# 191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30   4
# 192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30   4
# 193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30   3
# 194  13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   3
#
#                  phone   site      time            urine PartitionKey  \
# 190  Xiaomi 21081111RG  13777  16-31-45  ปกติ (เหลืองใส)        00000
# 191         iPhone12,3  06307  14-46-08  ปกติ (เหลืองใส)        00001
# 192         iPhone14,3  05328  15-27-45  ปกติ (เหลืองใส)        00001
# 193         iPhone13,4  06302  10-16-46  ปกติ (เหลืองใส)        00001
# 194          iPhone9,4  05059  12-26-38  ปกติ (เหลืองใส)        00001
#
#          sex  age
# 190  ไม่ระบุ    0
# 191     หญิง   47
# 192     หญิง   41
# 193     หญิง   55
# 194      ชาย   66

# %%
data_re.shape #ตรวจสอบขนาด
# Out:
# (38103, 11)

# %%
data_01 = data_re

# %%
data_01
# Out:
#         user                                RowKey       date  ov  \
# 190     6223                        kfpwuaqldj.png 2022-03-23   0
# 191    12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30   4
# 192    91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30   4
# 193    95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30   3
# 194    13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   3
# ...      ...                                   ...        ...  ..
# 39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11   1
# 39813  99999                        lnlohgqckf.png 2022-03-10   0
# 39814  99999                        vkdocpmjiv.png 2022-03-10   1
# 39815  99999                        vrvyfnvayq.png 2022-03-10   1
# 39816  99999                        zuhbtvyrce.png 2022-03-10   1
#
#                    phone   site      time                 urine PartitionKey  \
# 190    Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)        00000
# 191           iPhone12,3  06307  14-46-08       ปกติ (เหลืองใส)        00001
# 192           iPhone14,3  05328  15-27-45       ปกติ (เหลืองใส)        00001
# 193           iPhone13,4  06302  10-16-46       ปกติ (เหลืองใส)        00001
# 194            iPhone9,4  05059  12-26-38       ปกติ (เหลืองใส)        00001
# ...                  ...    ...       ...                   ...          ...
# 39812         iPhone14,2  99999  11-36-34                  ขุ่น        99999
# 39813   Samsung SM-G998B  99999  18-10-29               มีตะกอน        99999
# 39814   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง        99999
# 39815   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)        99999
# 39816   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)        99999
#
#            sex  age
# 190    ไม่ระบุ    0
# 191       หญิง   47
# 192       หญิง   41
# 193       หญิง   55
# 194        ชาย   66
# ...        ...  ...
# 39812  ไม่ระบุ    0
# 39813  ไม่ระบุ    0
# 39814  ไม่ระบุ    0
# 39815  ไม่ระบุ    0
# 39816  ไม่ระบุ    0
#
# [38103 rows x 11 columns]

# %% [markdown]
# ## ตารางที่ 2

# %%
data_hospital = pd.read_excel(os.path.join(path,'hospital_list.xlsx'))
data_hospital
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %%
data_hospital = data_hospital[['hcode','name','zone_name','province','amphur','tambon','name5','short_english']]      # เลือกเฉพาะคอลัมน์ที่ต้องการ
print(data_hospital.shape)
data_hospital
# Out:
# (17103, 8)
#        hcode                                               name  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...                                                ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#                       zone_name         province            amphur     tambon  \
# 0            สาขาพื้นที่(ระยอง)      สมุทรปราการ  เมืองสมุทรปราการ     ปากน้ำ
# 1          สาขาพื้นที่(สระบุรี)          นนทบุรี      เมืองนนทบุรี   บางกระสอ
# 2          สาขาพื้นที่(สระบุรี)         ปทุมธานี     เมืองปทุมธานี    บางปรอก
# 3          สาขาพื้นที่(สระบุรี)  พระนครศรีอยุธยา   พระนครศรีอยุธยา  หอรัตนไชย
# 4          สาขาพื้นที่(สระบุรี)          อ่างทอง      เมืองอ่างทอง    บ้านอิฐ
# ...                         ...              ...               ...        ...
# 17098     สาขาพื้นที่(พิษณุโลก)        อุตรดิตถ์    เมืองอุตรดิตถ์     ท่าอิฐ
# 17099      สาขาพื้นที่(ราชบุรี)  ประจวบคีรีขันธ์           กุยบุรี    กุยบุรี
# 17100      สาขาพื้นที่(ราชบุรี)          ราชบุรี           วัดเพลง    วัดเพลง
# 17101  สาขาพื้นที่(อุบลราชธานี)         ศรีสะเกษ     เมืองศรีสะเกษ     โพนข่า
# 17102      สาขาพื้นที่(ราชบุรี)          ราชบุรี             บางแพ    วังเย็น
#
#                           name5 short_english
# 0      สำนักงานสาธารณสุขจังหวัด           SPK
# 1      สำนักงานสาธารณสุขจังหวัด           NBI
# 2      สำนักงานสาธารณสุขจังหวัด           PTE
# 3      สำนักงานสาธารณสุขจังหวัด           AYA
# 4      สำนักงานสาธารณสุขจังหวัด           ATG
# ...                         ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.           RBR
#
# [17103 rows x 8 columns]

# %%
data_hospital.isnull().sum() # ตรวจสอบหาค่า missing
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
# Out:
# hcode            0
# name             0
# zone_name        0
# province         0
# amphur           0
# tambon           0
# name5            0
# short_english    0
# dtype: int64

# %%
data_hospital['name'] = data_hospital['name'].fillna('ไม่ระบุ') 
data_hospital['zone_name'] = data_hospital['zone_name'].fillna('ไม่ระบุ') 
data_hospital['amphur'] = data_hospital['amphur'].fillna('ไม่ระบุ') 
data_hospital['tambon'] = data_hospital['tambon'].fillna('ไม่ระบุ') 
data_hospital['name5'] = data_hospital['name5'].fillna('ไม่ระบุ') 
data_hospital['short_english'] = data_hospital['short_english'].fillna('ไม่ระบุ');
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_hospital.isnull().sum() # ตรวจสอบหาค่า missing
#.isnull() เพื่อระบุว่านิพจน์มีค่า Null หรือไม่
# Out:
# hcode            0
# name             0
# zone_name        0
# province         0
# amphur           0
# tambon           0
# name5            0
# short_english    0
# dtype: int64

# %%
data_use = data_01.merge(data_hospital,how='left',left_on='site',right_on='hcode')     # ใช้คำสั่ง merge เพื่อเชื่อมตาราง
data_use
# Out:
#         user                                RowKey       date  ov  \
# 0       6223                        kfpwuaqldj.png 2022-03-23   0
# 1      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30   4
# 2      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30   4
# 3      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30   3
# 4      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   3
# ...      ...                                   ...        ...  ..
# 38098  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A 2022-03-11   1
# 38099  99999                        lnlohgqckf.png 2022-03-10   0
# 38100  99999                        vkdocpmjiv.png 2022-03-10   1
# 38101  99999                        vrvyfnvayq.png 2022-03-10   1
# 38102  99999                        zuhbtvyrce.png 2022-03-10   1
#
#                    phone   site      time                 urine PartitionKey  \
# 0      Xiaomi 21081111RG  13777  16-31-45       ปกติ (เหลืองใส)        00000
# 1             iPhone12,3  06307  14-46-08       ปกติ (เหลืองใส)        00001
# 2             iPhone14,3  05328  15-27-45       ปกติ (เหลืองใส)        00001
# 3             iPhone13,4  06302  10-16-46       ปกติ (เหลืองใส)        00001
# 4              iPhone9,4  05059  12-26-38       ปกติ (เหลืองใส)        00001
# ...                  ...    ...       ...                   ...          ...
# 38098         iPhone14,2  99999  11-36-34                  ขุ่น        99999
# 38099   Samsung SM-G998B  99999  18-10-29               มีตะกอน        99999
# 38100   Samsung SM-G998B  99999  12-14-41  ขุ่น, มีเม็ดเลือดแดง        99999
# 38101   Samsung SM-G998B  99999  13-58-01       ปกติ (เหลืองใส)        99999
# 38102   Samsung SM-G998B  99999  13-57-58       ปกติ (เหลืองใส)        99999
#
#            sex  age  hcode                                               name  \
# 0      ไม่ระบุ    0  13777            โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น
# 1         หญิง   47  06307  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา
# 2         หญิง   41  05328        โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์
# 3         หญิง   55  06302                 โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง
# 4          ชาย   66  05059              โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่
# ...        ...  ...    ...                                                ...
# 38098  ไม่ระบุ    0    NaN                                                NaN
# 38099  ไม่ระบุ    0    NaN                                                NaN
# 38100  ไม่ระบุ    0    NaN                                                NaN
# 38101  ไม่ระบุ    0    NaN                                                NaN
# 38102  ไม่ระบุ    0    NaN                                                NaN
#
#                    zone_name   province        amphur    tambon  \
# 0       สาขาพื้นที่(ขอนแก่น)    ขอนแก่น  เมืองขอนแก่น   ในเมือง
# 1      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์         พิชัย  บ้านดารา
# 2       สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์       ฆ้องชัย  โคกสะอาด
# 3      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์        ฟากท่า   สองห้อง
# 4       สาขาพื้นที่(ขอนแก่น)  มหาสารคาม         นาดูน     หัวดง
# ...                      ...        ...           ...       ...
# 38098                    NaN        NaN           NaN       NaN
# 38099                    NaN        NaN           NaN       NaN
# 38100                    NaN        NaN           NaN       NaN
# 38101                    NaN        NaN           NaN       NaN
# 38102                    NaN        NaN           NaN       NaN
#
#                              name5 short_english
# 0                โรงพยาบาล นอก สธ.           KKN
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล           UTT
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล           KSN
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล           UTT
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล           MKM
# ...                            ...           ...
# 38098                          NaN           NaN
# 38099                          NaN           NaN
# 38100                          NaN           NaN
# 38101                          NaN           NaN
# 38102                          NaN           NaN
#
# [38103 rows x 19 columns]

# %%
data_use.isnull().sum() # ตรวจสอบหาค่า missing
# Out:
# user              0
# RowKey            0
# date              0
# ov                0
# phone             0
# site              0
# time              0
# urine             0
# PartitionKey      0
# sex               0
# age               0
# hcode            75
# name             75
# zone_name        75
# province         75
# amphur           75
# tambon           75
# name5            75
# short_english    75
# dtype: int64

# %%
data_use = data_use.dropna()
data_use
# Out:
#         user                                RowKey       date  ov  \
# 0       6223                        kfpwuaqldj.png 2022-03-23   0
# 1      12015  00859DB9-1BD9-4825-B246-3DC25EFD1924 2022-03-30   4
# 2      91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5 2022-03-30   4
# 3      95821  1914EE67-CD8F-47EE-A968-2772911AA5DF 2022-03-30   3
# 4      13361  1A219EE7-3647-4D7D-A8C0-AE638E69D889 2022-03-29   3
# ...      ...                                   ...        ...  ..
# 38086  68768  B7F36631-D2C4-4EB5-852D-790BFAFDFD71 2022-03-24   2
# 38087  68768  899A7591-50C9-40BC-9746-A831A08DE980 2022-03-24   0
# 38088  68768  BF39F27C-1B43-4C97-A034-D7A579BED2B6 2022-03-24   1
# 38089  68768  D8A3A9EA-929E-4CEB-BFDF-C9BE093EA663 2022-03-24   1
# 38090  99771  E04D3D60-B916-40A1-AE77-91CCD89DD084 2022-03-31   0
#
#                    phone   site      time            urine PartitionKey  \
# 0      Xiaomi 21081111RG  13777  16-31-45  ปกติ (เหลืองใส)        00000
# 1             iPhone12,3  06307  14-46-08  ปกติ (เหลืองใส)        00001
# 2             iPhone14,3  05328  15-27-45  ปกติ (เหลืองใส)        00001
# 3             iPhone13,4  06302  10-16-46  ปกติ (เหลืองใส)        00001
# 4              iPhone9,4  05059  12-26-38  ปกติ (เหลืองใส)        00001
# ...                  ...    ...       ...              ...          ...
# 38086         iPhone11,8  11088  10-30-22  ปกติ (เหลืองใส)        89170
# 38087         iPhone11,8  11088  10-29-37  ปกติ (เหลืองใส)        90470
# 38088         iPhone11,8  11088  10-24-40  ปกติ (เหลืองใส)        91123
# 38089         iPhone11,8  11088  10-25-32  ปกติ (เหลืองใส)        99444
# 38090         iPhone10,5  05396  11-03-40  ปกติ (เหลืองใส)        99771
#
#            sex  age  hcode                                               name  \
# 0      ไม่ระบุ    0  13777            โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น
# 1         หญิง   47  06307  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา
# 2         หญิง   41  05328        โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์
# 3         หญิง   55  06302                 โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง
# 4          ชาย   66  05059              โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านดอนดู่
# ...        ...  ...    ...                                                ...
# 38086  ไม่ระบุ    0  11088                                  โรงพยาบาลห้วยผึ้ง
# 38087  ไม่ระบุ    0  11088                                  โรงพยาบาลห้วยผึ้ง
# 38088  ไม่ระบุ    0  11088                                  โรงพยาบาลห้วยผึ้ง
# 38089  ไม่ระบุ    0  11088                                  โรงพยาบาลห้วยผึ้ง
# 38090  ไม่ระบุ    0  05396             โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านสูงเนิน
#
#                    zone_name   province        amphur        tambon  \
# 0       สาขาพื้นที่(ขอนแก่น)    ขอนแก่น  เมืองขอนแก่น       ในเมือง
# 1      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์         พิชัย      บ้านดารา
# 2       สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์       ฆ้องชัย      โคกสะอาด
# 3      สาขาพื้นที่(พิษณุโลก)  อุตรดิตถ์        ฟากท่า       สองห้อง
# 4       สาขาพื้นที่(ขอนแก่น)  มหาสารคาม         นาดูน         หัวดง
# ...                      ...        ...           ...           ...
# 38086   สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์      ห้วยผึ้ง  นิคมห้วยผึ้ง
# 38087   สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์      ห้วยผึ้ง  นิคมห้วยผึ้ง
# 38088   สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์      ห้วยผึ้ง  นิคมห้วยผึ้ง
# 38089   สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์      ห้วยผึ้ง  นิคมห้วยผึ้ง
# 38090   สาขาพื้นที่(ขอนแก่น)  กาฬสินธุ์        คำม่วง       เนินยาง
#
#                              name5 short_english
# 0                โรงพยาบาล นอก สธ.           KKN
# 1      โรงพยาบาลส่งเสริมสุขภาพตำบล           UTT
# 2      โรงพยาบาลส่งเสริมสุขภาพตำบล           KSN
# 3      โรงพยาบาลส่งเสริมสุขภาพตำบล           UTT
# 4      โรงพยาบาลส่งเสริมสุขภาพตำบล           MKM
# ...                            ...           ...
# 38086               โรงพยาบาลชุมชน           KSN
# 38087               โรงพยาบาลชุมชน           KSN
# 38088               โรงพยาบาลชุมชน           KSN
# 38089               โรงพยาบาลชุมชน           KSN
# 38090  โรงพยาบาลส่งเสริมสุขภาพตำบล           KSN
#
# [38028 rows x 19 columns]

# %%
data_use.to_csv(os.path.join(path,'data_use_edit.csv')) # save เข้า drive เพื่อนำไปทำ dashboard

# %% [markdown]
# #Dashboard
