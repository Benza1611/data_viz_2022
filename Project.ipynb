# %% [markdown]
# <a href="https://colab.research.google.com/github/Benza1611/data_viz_2022/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #นำเข้าข้อมูล

# %%
import pandas as pd #เรียกใช้งาน pandas
import os #เรียกใช้งาน os

# %%
from google.colab import drive #เปิดที่ google colab เรียก drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # ข้อมูลผู้ป่วยโควิด-19

# %% [markdown]
# ที่มา : https://data.go.th/dataset/covid-19-daily

# %% [markdown]
# ##ข้อมูลผู้ป่วย 12/01/2020 - 11/08/2021

# %%
data_covid1 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases.csv
data_covid1 ##เรียกดูตาราง
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985     11/8/2021     10/8/2021  หญิง   8.0   ปี    Thailand
# 816985  816986     11/8/2021     10/8/2021   ชาย  14.0   ปี    Thailand
# 816986  816987     11/8/2021     10/8/2021   ชาย  59.0   ปี    Thailand
# 816987  816988     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 816988  816989     11/8/2021     10/8/2021  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0                    NaN
# 1                    NaN
# 2                  เมือง
# 3                    NaN
# 4                    NaN
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %% [markdown]
# ##ข้อมูลผู้ป่วย 12/08/2021 - 25/10/2021

# %%
data_covid2 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-120864.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-120864.csv
data_covid2 ###เรียกดูตาราง
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ##ข้อมูลผู้ป่วย 26/10/2021 - 27/02/2022

# %%
data_covid3 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-271064.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-271064.csv
data_covid3 = data_covid3.drop('Unnamed: 11', axis=1) ##ตัด column ที่ชื่อ 'Unnamed: 11' ออก
data_covid3  ##เรียกดูตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                   ลำปาง        เมืองลำปาง
# 1                   ลำปาง        เมืองลำปาง
# 2                   ลำปาง          ห้างฉัตร
# 3                   ลำปาง          ห้างฉัตร
# 4                   ลำปาง        เมืองลำปาง
# ...                   ...               ...
# 1010454               NaN               NaN
# 1010455               NaN               NaN
# 1010456               NaN               NaN
# 1010457               NaN               NaN
# 1010458               NaN               NaN
#
# [1010459 rows x 11 columns]

# %% [markdown]
# ##ข้อมูลผู้ป่วย 28/02/2022 - 18/03/2022

# %%
data_covid4 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-280265.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-280265.csv
data_covid4  ##เรียกดูตาราง
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# ##รวมตาราง Covid

# %%
data_covid = pd.concat([data_covid1,data_covid2,data_covid3,data_covid4]) ##ทำการรวมตารางข้อมูลผู้ป่วยโควิด ในแนวแกน y ไว้ในตัวแปร data_covid
data_covid ##เรียกดูตาราง
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [3303169 rows x 11 columns]

# %% [markdown]
# ###ดูค่า Missing ของ data_covid

# %%
data_covid.isnull().any() ##ดูค่า Missing ในตาราง data_covid
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ### กำจัดค่า Missing

# %%
set(data_covid['province_of_isolation']) #ตรวจสอบค่าใน province_of_isolation
# Out:
# {nan,
#  'กทม',
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เลย',
#  'แพร่',
#  'แม่ฮ่องสอน'}

# %%
data_covid['province_of_isolation'].replace({'กทม':'กรุงเทพมหานคร','ขอนแก่น\xa0':'ขอนแก่น','ภููเก็ต':'ภูเก็ต'}, inplace=True ) #แทนที่ข้อมูลที่ผิดปกติ

# %%
set(data_covid['sex']) #ตรวจสอบค่าใน sex
# Out:
# {nan,
#  '\xa0หญิง',
#  'ช',
#  'ชาย',
#  'ญ',
#  'นาย',
#  'ร.ต.ท.',
#  'หญง',
#  'หญิง',
#  'หญิิง',
#  'หณิง',
#  'หห'}

# %%
data_covid['sex'].replace({'\xa0หญิง':'หญิง','ช':'ชาย','ญ':'หญิง','นาย':'ชาย','ร.ต.ท.':'ชาย','หญง':'หญิง','หญิง':'หญิง','หญิิง':'หญิง','หณิง':'หญิง','หห':'หญิง'}, inplace=True ) #แทนที่ข้อมูลที่ผิดปกติ

# %%
data_covid[['Unit']] = data_covid[['Unit']].fillna('ปี') ##แทนค่า NaN ใน Unit เป็น ปี
data_covid[['sex']] = data_covid[['sex']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_covid[['nationality']] = data_covid[['nationality']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_covid[['province_of_isolation']] =data_covid[['province_of_isolation']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_covid[['risk']] = data_covid[['risk']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
###data_covid = data_covid.fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
covid = data_covid[['No.','announce_date','sex','age','Unit','nationality','risk','province_of_isolation']] ##เลือกข้อมูลที่ต้องการ คือ 'No.','announce_date','sex','age','Unit','nationality','risk','province_of_isolation' เก็บไว้ในตัวแปร covid
covid ##เรียกดูตาราง
# Out:
#             No. announce_date   sex   age Unit nationality  \
# 0             1     12/1/2020  หญิง  61.0   ปี       China
# 1             2     17/1/2020  หญิง  74.0   ปี       China
# 2             3     22/1/2020  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020   ชาย  68.0   ปี       China
# 4             5     24/1/2020  หญิง  66.0   ปี       China
# ...         ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022  หญิง   NaN   ปี     ไม่ระบุ
# 433549  3303166     18/3/2022  หญิง   NaN   ปี     ไม่ระบุ
# 433550  3303167     18/3/2022  หญิง   NaN   ปี     ไม่ระบุ
# 433551  3303168     18/3/2022  หญิง   NaN   ปี     ไม่ระบุ
# 433552  3303169     18/3/2022  หญิง   NaN   ปี     ไม่ระบุ
#
#                                     risk province_of_isolation
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ                นครปฐม
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ               นนทบุรี
# ...                                  ...                   ...
# 433548                  ทัณฑสถาน/เรือนจำ         กรุงเทพมหานคร
# 433549                  ทัณฑสถาน/เรือนจำ         กรุงเทพมหานคร
# 433550                  ทัณฑสถาน/เรือนจำ         กรุงเทพมหานคร
# 433551                  ทัณฑสถาน/เรือนจำ                 สงขลา
# 433552                  ทัณฑสถาน/เรือนจำ                 สงขลา
#
# [3303169 rows x 8 columns]

# %%
covid.isnull().any() ##ดูค่า Missing ในตาราง covid
# Out:
# No.                      False
# announce_date            False
# sex                      False
# age                       True
# Unit                     False
# nationality              False
# risk                     False
# province_of_isolation    False
# dtype: bool

# %%
covid = covid.dropna() ##กำจัดค่า Missing
covid ## เรียกดูตาราง
# Out:
#             No. announce_date      sex   age Unit nationality  \
# 0             1     12/1/2020     หญิง  61.0   ปี       China
# 1             2     17/1/2020     หญิง  74.0   ปี       China
# 2             3     22/1/2020     หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020      ชาย  68.0   ปี       China
# 4             5     24/1/2020     หญิง  66.0   ปี       China
# ...         ...           ...      ...   ...  ...         ...
# 433445  3303062     18/3/2022  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 433446  3303063     18/3/2022  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 433447  3303064     18/3/2022  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 433448  3303065     18/3/2022  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 433449  3303066     18/3/2022  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                     risk province_of_isolation
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ                นครปฐม
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ               นนทบุรี
# ...                                  ...                   ...
# 433445                             อื่นๆ         กรุงเทพมหานคร
# 433446                             อื่นๆ         กรุงเทพมหานคร
# 433447                             อื่นๆ         กรุงเทพมหานคร
# 433448                             อื่นๆ         กรุงเทพมหานคร
# 433449                             อื่นๆ         กรุงเทพมหานคร
#
# [3036373 rows x 8 columns]

# %%
before = 3303169
after = 3036373
print(f'before = {before} \nafter = {after}\n which is {((before-after)/before)*100}')
# Out:
# before = 3303169
# after = 3036373
#  which is 8.076970933064581

# %%
covid['announce_date'] = pd.to_datetime(covid['announce_date'], format = "%d/%m/%Y")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
covid ##เรียกดูตาราง
# Out:
#             No. announce_date      sex   age Unit nationality  \
# 0             1    2020-01-12     หญิง  61.0   ปี       China
# 1             2    2020-01-17     หญิง  74.0   ปี       China
# 2             3    2020-01-22     หญิง  73.0   ปี    Thailand
# 3             4    2020-01-22      ชาย  68.0   ปี       China
# 4             5    2020-01-24     หญิง  66.0   ปี       China
# ...         ...           ...      ...   ...  ...         ...
# 433445  3303062    2022-03-18  ไม่ระบุ  43.0   ปี     ไม่ระบุ
# 433446  3303063    2022-03-18  ไม่ระบุ  21.0   ปี     ไม่ระบุ
# 433447  3303064    2022-03-18  ไม่ระบุ  22.0   ปี     ไม่ระบุ
# 433448  3303065    2022-03-18  ไม่ระบุ  25.0   ปี     ไม่ระบุ
# 433449  3303066    2022-03-18  ไม่ระบุ  64.0   ปี     ไม่ระบุ
#
#                                     risk province_of_isolation
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ                นครปฐม
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ         กรุงเทพมหานคร
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ               นนทบุรี
# ...                                  ...                   ...
# 433445                             อื่นๆ         กรุงเทพมหานคร
# 433446                             อื่นๆ         กรุงเทพมหานคร
# 433447                             อื่นๆ         กรุงเทพมหานคร
# 433448                             อื่นๆ         กรุงเทพมหานคร
# 433449                             อื่นๆ         กรุงเทพมหานคร
#
# [3036373 rows x 8 columns]

# %%
covid.info() ##ดูประเภทของข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3036373 entries, 0 to 433449
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   No.                    int64
#  1   announce_date          datetime64[ns]
#  2   sex                    object
#  3   age                    object
#  4   Unit                   object
#  5   nationality            object
#  6   risk                   object
#  7   province_of_isolation  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 208.5+ MB

# %% [markdown]
# ###จัดกลุ่มข้อมูลตามวัน

# %%
covid2 = covid[['announce_date','No.']]
covid3 = covid2.groupby('announce_date').count().sort_values(by=['announce_date'],ascending=False)
covid3
# Out:
#                  No.
# announce_date
# 2022-03-18     25905
# 2022-03-17     24078
# 2022-03-16     22254
# 2022-03-15     18783
# 2022-03-14     20852
# ...              ...
# 2020-01-25         1
# 2020-01-24         1
# 2020-01-22         2
# 2020-01-17         1
# 2020-01-12         1
#
# [741 rows x 1 columns]

# %%
covid4 = covid[['announce_date','sex']]
covid5 = covid4.groupby('announce_date').max().sort_values(by=['sex'],ascending=False)
covid5
# Out:
#                    sex
# announce_date
# 2022-03-18     ไม่ระบุ
# 2021-07-19     ไม่ระบุ
# 2021-08-10     ไม่ระบุ
# 2021-08-11     ไม่ระบุ
# 2021-08-12     ไม่ระบุ
# ...                ...
# 2020-11-16         ชาย
# 2020-11-17         ชาย
# 2020-07-21         ชาย
# 2020-07-20         ชาย
# 2020-06-05         ชาย
#
# [741 rows x 1 columns]

# %%
covid6 = covid[['announce_date','nationality']]
covid7 = covid6.groupby('announce_date').max().sort_values(by=['nationality'],ascending=False)
covid7
# Out:
#               nationality
# announce_date
# 2022-03-18        ไม่ระบุ
# 2021-07-26        ไม่ระบุ
# 2021-07-17        ไม่ระบุ
# 2021-07-18        ไม่ระบุ
# 2021-07-19        ไม่ระบุ
# ...                   ...
# 2020-01-28          China
# 2020-01-26          China
# 2020-01-25          China
# 2020-01-24          China
# 2020-01-12          China
#
# [741 rows x 1 columns]

# %%
covid8 = covid[['announce_date','province_of_isolation']]
covid9 = covid8.groupby('announce_date').max().sort_values(by=['province_of_isolation'],ascending=False)
covid9
# Out:
#               province_of_isolation
# announce_date
# 2020-11-06                  ไม่ระบุ
# 2021-01-04                  ไม่ระบุ
# 2021-03-19                  ไม่ระบุ
# 2020-03-16                  ไม่ระบุ
# 2020-07-13                  ไม่ระบุ
# ...                             ...
# 2020-09-04            กรุงเทพมหานคร
# 2020-09-05            กรุงเทพมหานคร
# 2020-09-07            กรุงเทพมหานคร
# 2020-09-09            กรุงเทพมหานคร
# 2020-01-12            กรุงเทพมหานคร
#
# [741 rows x 1 columns]

# %%
datacovid = covid3.merge(covid5,on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
datacovid ##เรียกดูตาราง
# Out:
#                  No.      sex
# announce_date
# 2022-03-18     25905  ไม่ระบุ
# 2022-03-17     24078  ไม่ระบุ
# 2022-03-16     22254  ไม่ระบุ
# 2022-03-15     18783  ไม่ระบุ
# 2022-03-14     20852  ไม่ระบุ
# ...              ...      ...
# 2020-01-25         1     หญิง
# 2020-01-24         1     หญิง
# 2020-01-22         2     หญิง
# 2020-01-17         1     หญิง
# 2020-01-12         1     หญิง
#
# [741 rows x 2 columns]

# %%
datacovid2 = datacovid.merge(covid7,on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
datacovid2 ##เรียกดูตาราง
# Out:
#                  No.      sex nationality
# announce_date
# 2022-03-18     25905  ไม่ระบุ     ไม่ระบุ
# 2022-03-17     24078  ไม่ระบุ     ไม่ระบุ
# 2022-03-16     22254  ไม่ระบุ     ไม่ระบุ
# 2022-03-15     18783  ไม่ระบุ     ไม่ระบุ
# 2022-03-14     20852  ไม่ระบุ     ไม่ระบุ
# ...              ...      ...         ...
# 2020-01-25         1     หญิง       China
# 2020-01-24         1     หญิง       China
# 2020-01-22         2     หญิง    Thailand
# 2020-01-17         1     หญิง       China
# 2020-01-12         1     หญิง       China
#
# [741 rows x 3 columns]

# %%
datacovid3 = datacovid2.merge(covid9,on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
datacovid3 ##เรียกดูตาราง
# Out:
#                  No.      sex nationality province_of_isolation
# announce_date
# 2022-03-18     25905  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 2022-03-17     24078  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 2022-03-16     22254  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 2022-03-15     18783  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 2022-03-14     20852  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# ...              ...      ...         ...                   ...
# 2020-01-25         1     หญิง       China         กรุงเทพมหานคร
# 2020-01-24         1     หญิง       China               นนทบุรี
# 2020-01-22         2     หญิง    Thailand                นครปฐม
# 2020-01-17         1     หญิง       China         กรุงเทพมหานคร
# 2020-01-12         1     หญิง       China         กรุงเทพมหานคร
#
# [741 rows x 4 columns]

# %% [markdown]
# # ข้อมูลภูมิภาค

# %% [markdown]
# ที่มา : https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B9%E0%B8%A1%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%84%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%84%E0%B8%97%E0%B8%A2

# %% [markdown]
# ##สร้างตารางข้อมูลจังหวัดที่แบ่งเป็นภูมิภาค

# %%
t = {'จังหวัด': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            'ภูมิภาค': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']
} #นำเข้าข้อมูล จังหวัดและภูมิภาค
data_t = pd.DataFrame.from_dict(t) #สร้างตาราง 
data_t ##เรียกดูตาราง
# Out:
#        จังหวัด             ภูมิภาค
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ
# ..         ...                 ...
# 72       พังงา                 ใต้
# 73      ภูเก็ต                 ใต้
# 74       ระนอง                 ใต้
# 75        สตูล                 ใต้
# 76        ตรัง                 ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ###ดูค่า Missing ของ data_t

# %%
data_t.isnull().any() ##ดูค่า Missing ในตาราง data_t
# Out:
# จังหวัด    False
# ภูมิภาค    False
# dtype: bool

# %% [markdown]
# #ข้อมูลการเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19

# %% [markdown]
# ที่มา : https://datagov.mot.go.th/dataset/covid-19

# %%
data_travel = pd.read_csv('/content/drive/My Drive/project2021 data/การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19.csv
data_travel ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0    12/1/2020                13,671                             86,534
# 1    13/1/2020                14,122                             81,181
# 2    14/1/2020                14,014                             82,506
# 3    15/1/2020                14,065                             83,364
# 4    16/1/2020                14,865                             83,492
# ..         ...                   ...                                ...
# 792  14/3/2022                12,188                              5,361
# 793  15/3/2022                10,613                              6,159
# 794  16/3/2022                11,176                              6,951
# 795  17/3/2022                12,579                              7,119
# 796  18/3/2022                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 792                             5,637              13,095
# 793                             5,553              11,127
# 794                             7,163              12,184
# 795                             5,928              13,750
# 796                             7,011              15,640
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ
# 0                             26,776                          25,949
# 1                             26,862                          24,685
# 2                             25,744                          23,256
# 3                             26,960                          24,958
# 4                             27,474                          23,618
# ..                               ...                             ...
# 792                              302                             134
# 793                                8                               3
# 794                              263                             220
# 795                               47                             106
# 796                              116                             117
#
# [797 rows x 7 columns]

# %% [markdown]
# ###ดูค่า Missing ของ data_travel

# %%
data_travel.isnull().any() ##ดูค่า Missing ในตาราง data_travel
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# dtype: bool

# %%
data_travel.info() ##ดูประเภทข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 797 entries, 0 to 796
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                797 non-null    object
#  1   ท่าอากาศยานสุวรรณภูมิ               797 non-null    object
#  2   ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  797 non-null    object
#  3   ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ   797 non-null    object
#  4   ท่าอากาศยานดอนเมือง                 797 non-null    object
#  5   ท่าอากาศยานดอนเมือง ขาเข้าประเทศ    797 non-null    object
#  6   ท่าอากาศยานดอนเมือง ขาออกประเทศ     797 non-null    object
# dtypes: object(7)
# memory usage: 43.7+ KB

# %%
tv = data_travel ##กำหนดตัวแปร tv มารับค่าตาราง data_travel
tv['date'] = pd.to_datetime(tv['date'], format = "%d/%m/%Y") ##กำหนด column 'date' ให้เป็น datetime โดยมีรูปแบบเป็น วัน/เดือน/ปี

# %%
tv  ### เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 792                             5,637              13,095
# 793                             5,553              11,127
# 794                             7,163              12,184
# 795                             5,928              13,750
# 796                             7,011              15,640
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ
# 0                             26,776                          25,949
# 1                             26,862                          24,685
# 2                             25,744                          23,256
# 3                             26,960                          24,958
# 4                             27,474                          23,618
# ..                               ...                             ...
# 792                              302                             134
# 793                                8                               3
# 794                              263                             220
# 795                               47                             106
# 796                              116                             117
#
# [797 rows x 7 columns]

# %% [markdown]
# #รวมตาราง

# %% [markdown]
# ##รวม 2 ตาราง

# %%
data1 = tv.merge(datacovid3,how='left',left_on='date',right_on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
data1 ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 792                             5,637              13,095
# 793                             5,553              11,127
# 794                             7,163              12,184
# 795                             5,928              13,750
# 796                             7,011              15,640
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ      No.  \
# 0                             26,776                          25,949      1.0
# 1                             26,862                          24,685      NaN
# 2                             25,744                          23,256      NaN
# 3                             26,960                          24,958      NaN
# 4                             27,474                          23,618      NaN
# ..                               ...                             ...      ...
# 792                              302                             134  20852.0
# 793                                8                               3  18783.0
# 794                              263                             220  22254.0
# 795                               47                             106  24078.0
# 796                              116                             117  25905.0
#
#          sex nationality province_of_isolation
# 0       หญิง       China         กรุงเทพมหานคร
# 1        NaN         NaN                   NaN
# 2        NaN         NaN                   NaN
# 3        NaN         NaN                   NaN
# 4        NaN         NaN                   NaN
# ..       ...         ...                   ...
# 792  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 793  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 794  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 795  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 796  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
#
# [797 rows x 11 columns]

# %% [markdown]
# ### ดูค่า Missing

# %%
data1.isnull().any() ##ดูค่า Missing ของข้อมูล
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# No.                                    True
# sex                                    True
# nationality                            True
# province_of_isolation                  True
# dtype: bool

# %% [markdown]
# ###กำจัดค่า Missing

# %%
data1[['No.']] = data1[['No.']].fillna('0') ##แทนค่า NaN ใน Unit เป็น ปี
data1 = data1.fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data1
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 792                             5,637              13,095
# 793                             5,553              11,127
# 794                             7,163              12,184
# 795                             5,928              13,750
# 796                             7,011              15,640
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ      No.  \
# 0                             26,776                          25,949      1.0
# 1                             26,862                          24,685        0
# 2                             25,744                          23,256        0
# 3                             26,960                          24,958        0
# 4                             27,474                          23,618        0
# ..                               ...                             ...      ...
# 792                              302                             134  20852.0
# 793                                8                               3  18783.0
# 794                              263                             220  22254.0
# 795                               47                             106  24078.0
# 796                              116                             117  25905.0
#
#          sex nationality province_of_isolation
# 0       หญิง       China         กรุงเทพมหานคร
# 1    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ
# 2    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ
# 3    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ
# 4    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ
# ..       ...         ...                   ...
# 792  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 793  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 794  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 795  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
# 796  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน
#
# [797 rows x 11 columns]

# %%
data1.isnull().any() ##ดูค่า Missing ของข้อมูล
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# No.                                   False
# sex                                   False
# nationality                           False
# province_of_isolation                 False
# dtype: bool

# %% [markdown]
# ##รวม 3 ตาราง

# %%
Project = data1.merge(data_t,how='left',left_on='province_of_isolation',right_on='จังหวัด') #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
Project ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 792                             5,637              13,095
# 793                             5,553              11,127
# 794                             7,163              12,184
# 795                             5,928              13,750
# 796                             7,011              15,640
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ      No.  \
# 0                             26,776                          25,949      1.0
# 1                             26,862                          24,685        0
# 2                             25,744                          23,256        0
# 3                             26,960                          24,958        0
# 4                             27,474                          23,618        0
# ..                               ...                             ...      ...
# 792                              302                             134  20852.0
# 793                                8                               3  18783.0
# 794                              263                             220  22254.0
# 795                               47                             106  24078.0
# 796                              116                             117  25905.0
#
#          sex nationality province_of_isolation        จังหวัด ภูมิภาค
# 0       หญิง       China         กรุงเทพมหานคร  กรุงเทพมหานคร    กลาง
# 1    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ            NaN     NaN
# 2    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ            NaN     NaN
# 3    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ            NaN     NaN
# 4    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ            NaN     NaN
# ..       ...         ...                   ...            ...     ...
# 792  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน   เหนือ
# 793  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน   เหนือ
# 794  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน   เหนือ
# 795  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน   เหนือ
# 796  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน   เหนือ
#
# [797 rows x 13 columns]

# %% [markdown]
# ### ดูค่า Missing

# %%
Project.isnull().any() ## ดูค่า Missing
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# No.                                   False
# sex                                   False
# nationality                           False
# province_of_isolation                 False
# จังหวัด                                True
# ภูมิภาค                                True
# dtype: bool

# %% [markdown]
# ###กำจัดค่า Missing

# %%
Project = Project.fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
Project
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 792                             5,637              13,095
# 793                             5,553              11,127
# 794                             7,163              12,184
# 795                             5,928              13,750
# 796                             7,011              15,640
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ      No.  \
# 0                             26,776                          25,949      1.0
# 1                             26,862                          24,685        0
# 2                             25,744                          23,256        0
# 3                             26,960                          24,958        0
# 4                             27,474                          23,618        0
# ..                               ...                             ...      ...
# 792                              302                             134  20852.0
# 793                                8                               3  18783.0
# 794                              263                             220  22254.0
# 795                               47                             106  24078.0
# 796                              116                             117  25905.0
#
#          sex nationality province_of_isolation        จังหวัด  ภูมิภาค
# 0       หญิง       China         กรุงเทพมหานคร  กรุงเทพมหานคร     กลาง
# 1    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ
# 2    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ
# 3    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ
# 4    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ
# ..       ...         ...                   ...            ...      ...
# 792  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ
# 793  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ
# 794  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ
# 795  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ
# 796  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ
#
# [797 rows x 13 columns]

# %%
Project.isnull().any() ## ดูค่า Missing
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# No.                                   False
# sex                                   False
# nationality                           False
# province_of_isolation                 False
# จังหวัด                               False
# ภูมิภาค                               False
# dtype: bool

# %%
Project['year'] = Project['date'].dt.year ##สร้าง column 'year' ขึ้นมาเพื่อรับค่า ปี ของ 'announce_date'
Project['month'] = Project['date'].dt.month ##สร้าง column 'mont' ขึ้นมาเพื่อรับค่า เดือน ของ 'announce_date'

# %%
Project
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 792                             5,637              13,095
# 793                             5,553              11,127
# 794                             7,163              12,184
# 795                             5,928              13,750
# 796                             7,011              15,640
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ      No.  \
# 0                             26,776                          25,949      1.0
# 1                             26,862                          24,685        0
# 2                             25,744                          23,256        0
# 3                             26,960                          24,958        0
# 4                             27,474                          23,618        0
# ..                               ...                             ...      ...
# 792                              302                             134  20852.0
# 793                                8                               3  18783.0
# 794                              263                             220  22254.0
# 795                               47                             106  24078.0
# 796                              116                             117  25905.0
#
#          sex nationality province_of_isolation        จังหวัด  ภูมิภาค  year  \
# 0       หญิง       China         กรุงเทพมหานคร  กรุงเทพมหานคร     กลาง  2020
# 1    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ  2020
# 2    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ  2020
# 3    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ  2020
# 4    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ  2020
# ..       ...         ...                   ...            ...      ...   ...
# 792  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2022
# 793  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2022
# 794  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2022
# 795  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2022
# 796  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2022
#
#      month
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 792      3
# 793      3
# 794      3
# 795      3
# 796      3
#
# [797 rows x 15 columns]

# %% [markdown]
# #เลือกข้อมูลมาทำ Dashboard

# %%
Project_2021 = Project[(Project['year'] == 2020) | (Project['year'] == 2021)] ### เลือกข้อมูลที่มีค่า year เท่ากับ 2020 เก็บไว้ในตัวแปร Project_2020
Project_2021 ## เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 715 2021-12-27                15,851                              6,353
# 716 2021-12-28                16,075                              7,379
# 717 2021-12-29                16,445                              8,047
# 718 2021-12-30                17,564                              6,418
# 719 2021-12-31                15,027                              6,495
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 715                             3,248              18,347
# 716                             3,704              17,728
# 717                             5,500              19,509
# 718                             4,577              18,949
# 719                             4,538              17,979
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ     No.  \
# 0                             26,776                          25,949     1.0
# 1                             26,862                          24,685       0
# 2                             25,744                          23,256       0
# 3                             26,960                          24,958       0
# 4                             27,474                          23,618       0
# ..                               ...                             ...     ...
# 715                              196                              66  2228.0
# 716                              123                              12  2061.0
# 717                              165                             164  2450.0
# 718                                0                              15  2550.0
# 719                               24                              47  2759.0
#
#          sex nationality province_of_isolation        จังหวัด  ภูมิภาค  year  \
# 0       หญิง       China         กรุงเทพมหานคร  กรุงเทพมหานคร     กลาง  2020
# 1    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ  2020
# 2    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ  2020
# 3    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ  2020
# 4    ไม่ระบุ     ไม่ระบุ               ไม่ระบุ        ไม่ระบุ  ไม่ระบุ  2020
# ..       ...         ...                   ...            ...      ...   ...
# 715  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2021
# 716  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2021
# 717  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2021
# 718  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2021
# 719  ไม่ระบุ     ไม่ระบุ            แม่ฮ่องสอน     แม่ฮ่องสอน    เหนือ  2021
#
#      month
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 715     12
# 716     12
# 717     12
# 718     12
# 719     12
#
# [720 rows x 15 columns]

# %%
Project_2021.to_csv('Project_20_21.csv', encoding = 'utf-8') ##บันทึก Project_2020 เป็นไฟล์ .csv
