# %% [markdown]
# <a href="https://colab.research.google.com/github/Benza1611/data_viz_2022/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #นำเข้าข้อมูล

# %%
import pandas as pd #เรียกใช้งาน pandas
import os #เรียกใช้งาน os

# %%
from google.colab import drive #เปิดที่ google colab เรียก drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # ข้อมูลผู้ป่วยโควิด-19

# %% [markdown]
# ที่มา : https://data.go.th/dataset/covid-19-daily

# %% [markdown]
# ##ข้อมูลผู้ป่วย 12/01/2020 - 11/08/2021

# %%
data_covid1 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases.csv
data_covid1 ##เรียกดูตาราง
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985     11/8/2021     10/8/2021  หญิง   8.0   ปี    Thailand
# 816985  816986     11/8/2021     10/8/2021   ชาย  14.0   ปี    Thailand
# 816986  816987     11/8/2021     10/8/2021   ชาย  59.0   ปี    Thailand
# 816987  816988     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 816988  816989     11/8/2021     10/8/2021  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0                    NaN
# 1                    NaN
# 2                  เมือง
# 3                    NaN
# 4                    NaN
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %% [markdown]
# ##ข้อมูลผู้ป่วย 12/08/2021 - 25/10/2021

# %%
data_covid2 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-120864.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-120864.csv
data_covid2 ###เรียกดูตาราง
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ##ข้อมูลผู้ป่วย 26/10/2021 - 27/02/2022

# %%
data_covid3 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-271064.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-271064.csv
data_covid3 = data_covid3.drop('Unnamed: 11', axis=1) ##ตัด column ที่ชื่อ 'Unnamed: 11' ออก
data_covid3  ##เรียกดูตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                   ลำปาง        เมืองลำปาง
# 1                   ลำปาง        เมืองลำปาง
# 2                   ลำปาง          ห้างฉัตร
# 3                   ลำปาง          ห้างฉัตร
# 4                   ลำปาง        เมืองลำปาง
# ...                   ...               ...
# 1010454               NaN               NaN
# 1010455               NaN               NaN
# 1010456               NaN               NaN
# 1010457               NaN               NaN
# 1010458               NaN               NaN
#
# [1010459 rows x 11 columns]

# %% [markdown]
# ##ข้อมูลผู้ป่วย 28/02/2022 - 18/03/2022

# %%
data_covid4 = pd.read_csv('/content/drive/My Drive/project2021 data/confirmed-cases-since-280265.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> confirmed-cases-since-280265.csv
data_covid4  ##เรียกดูตาราง
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# ##รวมตาราง Covid

# %%
data_covid = pd.concat([data_covid1,data_covid2,data_covid3,data_covid4]) ##ทำการรวมตารางข้อมูลผู้ป่วยโควิด ในแนวแกน y ไว้ในตัวแปร data_covid
data_covid ##เรียกดูตาราง
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [3303169 rows x 11 columns]

# %% [markdown]
# ###ดูค่า Missing ของ data_covid

# %%
data_covid.isnull().any() ##ดูค่า Missing ในตาราง data_covid
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ### กำจัดค่า Missing

# %%
set(data_covid['province_of_isolation']) #ตรวจสอบค่าใน province_of_isolation
# Out:
# {nan,
#  'กทม',
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เพชรบุรี',
#  'เพชรบูรณ์',
#  'เลย',
#  'แพร่',
#  'แม่ฮ่องสอน'}

# %%
data_covid['province_of_isolation'].replace({'กทม':'กรุงเทพมหานคร','ขอนแก่น\xa0':'ขอนแก่น','ภููเก็ต':'ภูเก็ต'}, inplace=True ) #แทนที่ข้อมูลที่ผิดปกติ

# %%
set(data_covid['sex']) #ตรวจสอบค่าใน sex
# Out:
# {nan,
#  '\xa0หญิง',
#  'ช',
#  'ชาย',
#  'ญ',
#  'นาย',
#  'ร.ต.ท.',
#  'หญง',
#  'หญิง',
#  'หญิิง',
#  'หณิง',
#  'หห'}

# %%
data_covid['sex'].replace({'\xa0หญิง':'หญิง','ช':'ชาย','ญ':'หญิง','นาย':'ชาย','ร.ต.ท.':'ชาย','หญง':'หญิง','หญิง':'หญิง','หญิิง':'หญิง','หณิง':'หญิง','หห':'หญิง'}, inplace=True ) #แทนที่ข้อมูลที่ผิดปกติ

# %%
data_covid[['Unit']] = data_covid[['Unit']].fillna('ปี') ##แทนค่า NaN ใน Unit เป็น ปี
data_covid[['sex']] = data_covid[['sex']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_covid[['nationality']] = data_covid[['nationality']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_covid[['province_of_isolation']] =data_covid[['province_of_isolation']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
data_covid[['risk']] = data_covid[['risk']].fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ
###data_covid = data_covid.fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
covid = data_covid[['No.','announce_date','sex','nationality','province_of_isolation']] ##เลือกข้อมูลที่ต้องการ คือ 'No.','announce_date','sex','age','Unit','nationality','risk','province_of_isolation' เก็บไว้ในตัวแปร covid
covid ##เรียกดูตาราง
# Out:
#             No. announce_date   sex nationality province_of_isolation
# 0             1     12/1/2020  หญิง       China         กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง       China         กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง    Thailand                นครปฐม
# 3             4     22/1/2020   ชาย       China         กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง       China               นนทบุรี
# ...         ...           ...   ...         ...                   ...
# 433548  3303165     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433549  3303166     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433550  3303167     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433551  3303168     18/3/2022  หญิง     ไม่ระบุ                 สงขลา
# 433552  3303169     18/3/2022  หญิง     ไม่ระบุ                 สงขลา
#
# [3303169 rows x 5 columns]

# %%
covid.isnull().any() ##ดูค่า Missing ในตาราง covid
# Out:
# No.                      False
# announce_date            False
# sex                      False
# nationality              False
# province_of_isolation    False
# dtype: bool

# %%
covid = covid.dropna() ##กำจัดค่า Missing
covid ## เรียกดูตาราง
# Out:
#             No. announce_date   sex nationality province_of_isolation
# 0             1     12/1/2020  หญิง       China         กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง       China         กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง    Thailand                นครปฐม
# 3             4     22/1/2020   ชาย       China         กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง       China               นนทบุรี
# ...         ...           ...   ...         ...                   ...
# 433548  3303165     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433549  3303166     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433550  3303167     18/3/2022  หญิง     ไม่ระบุ         กรุงเทพมหานคร
# 433551  3303168     18/3/2022  หญิง     ไม่ระบุ                 สงขลา
# 433552  3303169     18/3/2022  หญิง     ไม่ระบุ                 สงขลา
#
# [3303169 rows x 5 columns]

# %%
before = 3303169
after = 3036373
print(f'before = {before} \nafter = {after}\n which is {((before-after)/before)*100}')
# Out:
# before = 3303169
# after = 3036373
#  which is 8.076970933064581

# %%
covid['announce_date'] = pd.to_datetime(covid['announce_date'], format = "%d/%m/%Y")

# %%
covid = covid.assign(เพศ = covid[['sex']])
covid = covid.assign(สัญชาติ = covid[['nationality']])
covid = covid.assign(จังหวัดที่กักตัว = covid[['province_of_isolation']])
covid ##เรียกดูตาราง
# Out:
#             No. announce_date   sex nationality province_of_isolation   เพศ  \
# 0             1    2020-01-12  หญิง       China         กรุงเทพมหานคร  หญิง
# 1             2    2020-01-17  หญิง       China         กรุงเทพมหานคร  หญิง
# 2             3    2020-01-22  หญิง    Thailand                นครปฐม  หญิง
# 3             4    2020-01-22   ชาย       China         กรุงเทพมหานคร   ชาย
# 4             5    2020-01-24  หญิง       China               นนทบุรี  หญิง
# ...         ...           ...   ...         ...                   ...   ...
# 433548  3303165    2022-03-18  หญิง     ไม่ระบุ         กรุงเทพมหานคร  หญิง
# 433549  3303166    2022-03-18  หญิง     ไม่ระบุ         กรุงเทพมหานคร  หญิง
# 433550  3303167    2022-03-18  หญิง     ไม่ระบุ         กรุงเทพมหานคร  หญิง
# 433551  3303168    2022-03-18  หญิง     ไม่ระบุ                 สงขลา  หญิง
# 433552  3303169    2022-03-18  หญิง     ไม่ระบุ                 สงขลา  หญิง
#
#          สัญชาติ จังหวัดที่กักตัว
# 0          China    กรุงเทพมหานคร
# 1          China    กรุงเทพมหานคร
# 2       Thailand           นครปฐม
# 3          China    กรุงเทพมหานคร
# 4          China          นนทบุรี
# ...          ...              ...
# 433548   ไม่ระบุ    กรุงเทพมหานคร
# 433549   ไม่ระบุ    กรุงเทพมหานคร
# 433550   ไม่ระบุ    กรุงเทพมหานคร
# 433551   ไม่ระบุ            สงขลา
# 433552   ไม่ระบุ            สงขลา
#
# [3303169 rows x 8 columns]

# %%
covid.info() ##ดูประเภทของข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3303169 entries, 0 to 433552
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   No.                    int64
#  1   announce_date          datetime64[ns]
#  2   sex                    object
#  3   nationality            object
#  4   province_of_isolation  object
#  5   เพศ                    object
#  6   สัญชาติ                object
#  7   จังหวัดที่กักตัว       object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 226.8+ MB

# %% [markdown]
# ###จัดกลุ่มข้อมูลตามวัน

# %%
A0 = covid[['announce_date','No.']].groupby(['announce_date']).count()
A0
# Out:
#                  No.
# announce_date
# 2020-01-12         1
# 2020-01-17         1
# 2020-01-22         2
# 2020-01-24         1
# 2020-01-25         1
# ...              ...
# 2022-03-14     22130
# 2022-03-15     19742
# 2022-03-16     23945
# 2022-03-17     25456
# 2022-03-18     27071
#
# [741 rows x 1 columns]

# %%
A =  covid[['announce_date','sex','เพศ']].groupby(['announce_date','sex']).count()
A
# Out:
#                          เพศ
# announce_date sex
# 2020-01-12    หญิง         1
# 2020-01-17    หญิง         1
# 2020-01-22    ชาย          1
#               หญิง         1
# 2020-01-24    หญิง         1
# ...                      ...
# 2022-03-17    หญิง     14349
#               ไม่ระบุ   1025
# 2022-03-18    ชาย      10549
#               หญิง     14434
#               ไม่ระบุ   2088
#
# [1753 rows x 1 columns]

# %%
B =  covid[['announce_date','sex','เพศ']].groupby(['announce_date','sex']).min()
B
# Out:
#                            เพศ
# announce_date sex
# 2020-01-12    หญิง        หญิง
# 2020-01-17    หญิง        หญิง
# 2020-01-22    ชาย          ชาย
#               หญิง        หญิง
# 2020-01-24    หญิง        หญิง
# ...                        ...
# 2022-03-17    หญิง        หญิง
#               ไม่ระบุ  ไม่ระบุ
# 2022-03-18    ชาย          ชาย
#               หญิง        หญิง
#               ไม่ระบุ  ไม่ระบุ
#
# [1753 rows x 1 columns]

# %%
C = B.merge(A,on= ['announce_date','sex']) #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
C
# Out:
#                          เพศ_x  เพศ_y
# announce_date sex
# 2020-01-12    หญิง        หญิง      1
# 2020-01-17    หญิง        หญิง      1
# 2020-01-22    ชาย          ชาย      1
#               หญิง        หญิง      1
# 2020-01-24    หญิง        หญิง      1
# ...                        ...    ...
# 2022-03-17    หญิง        หญิง  14349
#               ไม่ระบุ  ไม่ระบุ   1025
# 2022-03-18    ชาย          ชาย  10549
#               หญิง        หญิง  14434
#               ไม่ระบุ  ไม่ระบุ   2088
#
# [1753 rows x 2 columns]

# %%
A2 = covid[['announce_date','province_of_isolation','จังหวัดที่กักตัว']].groupby(['announce_date','province_of_isolation']).count()
A2
# Out:
#                                      จังหวัดที่กักตัว
# announce_date province_of_isolation
# 2020-01-12    กรุงเทพมหานคร                         1
# 2020-01-17    กรุงเทพมหานคร                         1
# 2020-01-22    กรุงเทพมหานคร                         1
#               นครปฐม                                1
# 2020-01-24    นนทบุรี                               1
# ...                                               ...
# 2022-03-18    เพชรบุรี                            355
#               เพชรบูรณ์                           101
#               เลย                                 139
#               แพร่                                 73
#               แม่ฮ่องสอน                           34
#
# [27130 rows x 1 columns]

# %%
B2 =  covid[['announce_date','province_of_isolation','จังหวัดที่กักตัว']].groupby(['announce_date','province_of_isolation']).min()
B2
# Out:
#                                     จังหวัดที่กักตัว
# announce_date province_of_isolation
# 2020-01-12    กรุงเทพมหานคร            กรุงเทพมหานคร
# 2020-01-17    กรุงเทพมหานคร            กรุงเทพมหานคร
# 2020-01-22    กรุงเทพมหานคร            กรุงเทพมหานคร
#               นครปฐม                          นครปฐม
# 2020-01-24    นนทบุรี                        นนทบุรี
# ...                                              ...
# 2022-03-18    เพชรบุรี                      เพชรบุรี
#               เพชรบูรณ์                    เพชรบูรณ์
#               เลย                                เลย
#               แพร่                              แพร่
#               แม่ฮ่องสอน                  แม่ฮ่องสอน
#
# [27130 rows x 1 columns]

# %%
C2 = B2.merge(A2,on= ['announce_date','province_of_isolation']) #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
C2
# Out:
#                                     จังหวัดที่กักตัว_x  จังหวัดที่กักตัว_y
# announce_date province_of_isolation
# 2020-01-12    กรุงเทพมหานคร              กรุงเทพมหานคร                   1
# 2020-01-17    กรุงเทพมหานคร              กรุงเทพมหานคร                   1
# 2020-01-22    กรุงเทพมหานคร              กรุงเทพมหานคร                   1
#               นครปฐม                            นครปฐม                   1
# 2020-01-24    นนทบุรี                          นนทบุรี                   1
# ...                                                ...                 ...
# 2022-03-18    เพชรบุรี                        เพชรบุรี                 355
#               เพชรบูรณ์                      เพชรบูรณ์                 101
#               เลย                                  เลย                 139
#               แพร่                                แพร่                  73
#               แม่ฮ่องสอน                    แม่ฮ่องสอน                  34
#
# [27130 rows x 2 columns]

# %%
Mix = A0.merge(C,on= ['announce_date']) #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
Mix
# Out:
#                  No.    เพศ_x  เพศ_y
# announce_date
# 2020-01-12         1     หญิง      1
# 2020-01-17         1     หญิง      1
# 2020-01-22         2      ชาย      1
# 2020-01-22         2     หญิง      1
# 2020-01-24         1     หญิง      1
# ...              ...      ...    ...
# 2022-03-17     25456     หญิง  14349
# 2022-03-17     25456  ไม่ระบุ   1025
# 2022-03-18     27071      ชาย  10549
# 2022-03-18     27071     หญิง  14434
# 2022-03-18     27071  ไม่ระบุ   2088
#
# [1753 rows x 3 columns]

# %%
Mix2 = Mix.merge(C2,on= ['announce_date']) #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
Mix2
# Out:
#                  No.    เพศ_x  เพศ_y จังหวัดที่กักตัว_x  จังหวัดที่กักตัว_y
# announce_date
# 2020-01-12         1     หญิง      1      กรุงเทพมหานคร                   1
# 2020-01-17         1     หญิง      1      กรุงเทพมหานคร                   1
# 2020-01-22         2      ชาย      1      กรุงเทพมหานคร                   1
# 2020-01-22         2      ชาย      1             นครปฐม                   1
# 2020-01-22         2     หญิง      1      กรุงเทพมหานคร                   1
# ...              ...      ...    ...                ...                 ...
# 2022-03-18     27071  ไม่ระบุ   2088           เพชรบุรี                 355
# 2022-03-18     27071  ไม่ระบุ   2088          เพชรบูรณ์                 101
# 2022-03-18     27071  ไม่ระบุ   2088                เลย                 139
# 2022-03-18     27071  ไม่ระบุ   2088               แพร่                  73
# 2022-03-18     27071  ไม่ระบุ   2088         แม่ฮ่องสอน                  34
#
# [78582 rows x 5 columns]

# %% [markdown]
# # ข้อมูลภูมิภาค

# %% [markdown]
# ที่มา : https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B9%E0%B8%A1%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%84%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%84%E0%B8%97%E0%B8%A2

# %% [markdown]
# ##สร้างตารางข้อมูลจังหวัดที่แบ่งเป็นภูมิภาค

# %%
t = {'จังหวัด': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            'ภูมิภาค': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']
} #นำเข้าข้อมูล จังหวัดและภูมิภาค
data_t = pd.DataFrame.from_dict(t) #สร้างตาราง 
data_t ##เรียกดูตาราง
# Out:
#        จังหวัด             ภูมิภาค
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ
# ..         ...                 ...
# 72       พังงา                 ใต้
# 73      ภูเก็ต                 ใต้
# 74       ระนอง                 ใต้
# 75        สตูล                 ใต้
# 76        ตรัง                 ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ###ดูค่า Missing ของ data_t

# %%
data_t.isnull().any() ##ดูค่า Missing ในตาราง data_t
# Out:
# จังหวัด    False
# ภูมิภาค    False
# dtype: bool

# %% [markdown]
# #ข้อมูลการเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19

# %% [markdown]
# ที่มา : https://datagov.mot.go.th/dataset/covid-19

# %%
data_travel = pd.read_csv('/content/drive/My Drive/project2021 data/การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19.csv') #เข้าไปที่ my drive -> โฟลเดอร์ project2021 data -> การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19.csv
data_travel ##เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0    12/1/2020                13,671                             86,534
# 1    13/1/2020                14,122                             81,181
# 2    14/1/2020                14,014                             82,506
# 3    15/1/2020                14,065                             83,364
# 4    16/1/2020                14,865                             83,492
# ..         ...                   ...                                ...
# 792  14/3/2022                12,188                              5,361
# 793  15/3/2022                10,613                              6,159
# 794  16/3/2022                11,176                              6,951
# 795  17/3/2022                12,579                              7,119
# 796  18/3/2022                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 792                             5,637              13,095
# 793                             5,553              11,127
# 794                             7,163              12,184
# 795                             5,928              13,750
# 796                             7,011              15,640
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ
# 0                             26,776                          25,949
# 1                             26,862                          24,685
# 2                             25,744                          23,256
# 3                             26,960                          24,958
# 4                             27,474                          23,618
# ..                               ...                             ...
# 792                              302                             134
# 793                                8                               3
# 794                              263                             220
# 795                               47                             106
# 796                              116                             117
#
# [797 rows x 7 columns]

# %% [markdown]
# ###ดูค่า Missing ของ data_travel

# %%
data_travel.isnull().any() ##ดูค่า Missing ในตาราง data_travel
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# dtype: bool

# %%
data_travel.info() ##ดูประเภทข้อมูล
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 797 entries, 0 to 796
# Data columns (total 7 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                797 non-null    object
#  1   ท่าอากาศยานสุวรรณภูมิ               797 non-null    object
#  2   ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  797 non-null    object
#  3   ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ   797 non-null    object
#  4   ท่าอากาศยานดอนเมือง                 797 non-null    object
#  5   ท่าอากาศยานดอนเมือง ขาเข้าประเทศ    797 non-null    object
#  6   ท่าอากาศยานดอนเมือง ขาออกประเทศ     797 non-null    object
# dtypes: object(7)
# memory usage: 43.7+ KB

# %%
tv = data_travel ##กำหนดตัวแปร tv มารับค่าตาราง data_travel
tv['date'] = pd.to_datetime(tv['date'], format = "%d/%m/%Y") ##กำหนด column 'date' ให้เป็น datetime โดยมีรูปแบบเป็น วัน/เดือน/ปี

# %%
tv  ### เรียกดูตาราง
# Out:
#           date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0   2020-01-12                13,671                             86,534
# 1   2020-01-13                14,122                             81,181
# 2   2020-01-14                14,014                             82,506
# 3   2020-01-15                14,065                             83,364
# 4   2020-01-16                14,865                             83,492
# ..         ...                   ...                                ...
# 792 2022-03-14                12,188                              5,361
# 793 2022-03-15                10,613                              6,159
# 794 2022-03-16                11,176                              6,951
# 795 2022-03-17                12,579                              7,119
# 796 2022-03-18                14,085                              8,004
#
#     ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                              67,815              29,869
# 1                              68,008              30,536
# 2                              63,819              30,177
# 3                              66,785              31,569
# 4                              65,458              33,014
# ..                                ...                 ...
# 792                             5,637              13,095
# 793                             5,553              11,127
# 794                             7,163              12,184
# 795                             5,928              13,750
# 796                             7,011              15,640
#
#     ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ
# 0                             26,776                          25,949
# 1                             26,862                          24,685
# 2                             25,744                          23,256
# 3                             26,960                          24,958
# 4                             27,474                          23,618
# ..                               ...                             ...
# 792                              302                             134
# 793                                8                               3
# 794                              263                             220
# 795                               47                             106
# 796                              116                             117
#
# [797 rows x 7 columns]

# %% [markdown]
# #รวมตาราง

# %% [markdown]
# ##รวม 2 ตาราง

# %%
data1 = tv.merge(Mix2,how='left',left_on='date',right_on='announce_date') #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
data1 ##เรียกดูตาราง
# Out:
#             date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0     2020-01-12                13,671                             86,534
# 1     2020-01-13                14,122                             81,181
# 2     2020-01-14                14,014                             82,506
# 3     2020-01-15                14,065                             83,364
# 4     2020-01-16                14,865                             83,492
# ...          ...                   ...                                ...
# 78633 2022-03-18                14,085                              8,004
# 78634 2022-03-18                14,085                              8,004
# 78635 2022-03-18                14,085                              8,004
# 78636 2022-03-18                14,085                              8,004
# 78637 2022-03-18                14,085                              8,004
#
#       ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                                67,815              29,869
# 1                                68,008              30,536
# 2                                63,819              30,177
# 3                                66,785              31,569
# 4                                65,458              33,014
# ...                                 ...                 ...
# 78633                             7,011              15,640
# 78634                             7,011              15,640
# 78635                             7,011              15,640
# 78636                             7,011              15,640
# 78637                             7,011              15,640
#
#       ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ  \
# 0                               26,776                          25,949
# 1                               26,862                          24,685
# 2                               25,744                          23,256
# 3                               26,960                          24,958
# 4                               27,474                          23,618
# ...                                ...                             ...
# 78633                              116                             117
# 78634                              116                             117
# 78635                              116                             117
# 78636                              116                             117
# 78637                              116                             117
#
#            No.    เพศ_x   เพศ_y จังหวัดที่กักตัว_x  จังหวัดที่กักตัว_y
# 0          1.0     หญิง     1.0      กรุงเทพมหานคร                 1.0
# 1          NaN      NaN     NaN                NaN                 NaN
# 2          NaN      NaN     NaN                NaN                 NaN
# 3          NaN      NaN     NaN                NaN                 NaN
# 4          NaN      NaN     NaN                NaN                 NaN
# ...        ...      ...     ...                ...                 ...
# 78633  27071.0  ไม่ระบุ  2088.0           เพชรบุรี               355.0
# 78634  27071.0  ไม่ระบุ  2088.0          เพชรบูรณ์               101.0
# 78635  27071.0  ไม่ระบุ  2088.0                เลย               139.0
# 78636  27071.0  ไม่ระบุ  2088.0               แพร่                73.0
# 78637  27071.0  ไม่ระบุ  2088.0         แม่ฮ่องสอน                34.0
#
# [78638 rows x 12 columns]

# %% [markdown]
# ### ดูค่า Missing

# %%
data1.isnull().any() ##ดูค่า Missing ของข้อมูล
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# No.                                    True
# เพศ_x                                  True
# เพศ_y                                  True
# จังหวัดที่กักตัว_x                     True
# จังหวัดที่กักตัว_y                     True
# dtype: bool

# %% [markdown]
# ###กำจัดค่า Missing

# %%
data1[['No.']] = data1[['No.']].fillna('0') ##แทนค่า NaN ใน Unit เป็น ปี
data1 = data1.fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
data1
# Out:
#             date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0     2020-01-12                13,671                             86,534
# 1     2020-01-13                14,122                             81,181
# 2     2020-01-14                14,014                             82,506
# 3     2020-01-15                14,065                             83,364
# 4     2020-01-16                14,865                             83,492
# ...          ...                   ...                                ...
# 78633 2022-03-18                14,085                              8,004
# 78634 2022-03-18                14,085                              8,004
# 78635 2022-03-18                14,085                              8,004
# 78636 2022-03-18                14,085                              8,004
# 78637 2022-03-18                14,085                              8,004
#
#       ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                                67,815              29,869
# 1                                68,008              30,536
# 2                                63,819              30,177
# 3                                66,785              31,569
# 4                                65,458              33,014
# ...                                 ...                 ...
# 78633                             7,011              15,640
# 78634                             7,011              15,640
# 78635                             7,011              15,640
# 78636                             7,011              15,640
# 78637                             7,011              15,640
#
#       ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ  \
# 0                               26,776                          25,949
# 1                               26,862                          24,685
# 2                               25,744                          23,256
# 3                               26,960                          24,958
# 4                               27,474                          23,618
# ...                                ...                             ...
# 78633                              116                             117
# 78634                              116                             117
# 78635                              116                             117
# 78636                              116                             117
# 78637                              116                             117
#
#            No.    เพศ_x    เพศ_y จังหวัดที่กักตัว_x จังหวัดที่กักตัว_y
# 0          1.0     หญิง      1.0      กรุงเทพมหานคร                1.0
# 1            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 2            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 3            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 4            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# ...        ...      ...      ...                ...                ...
# 78633  27071.0  ไม่ระบุ   2088.0           เพชรบุรี              355.0
# 78634  27071.0  ไม่ระบุ   2088.0          เพชรบูรณ์              101.0
# 78635  27071.0  ไม่ระบุ   2088.0                เลย              139.0
# 78636  27071.0  ไม่ระบุ   2088.0               แพร่               73.0
# 78637  27071.0  ไม่ระบุ   2088.0         แม่ฮ่องสอน               34.0
#
# [78638 rows x 12 columns]

# %%
data1.isnull().any() ##ดูค่า Missing ของข้อมูล
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# No.                                   False
# เพศ_x                                 False
# เพศ_y                                 False
# จังหวัดที่กักตัว_x                    False
# จังหวัดที่กักตัว_y                    False
# dtype: bool

# %% [markdown]
# ##รวม 3 ตาราง

# %%
Project = data1.merge(data_t,how='left',left_on='จังหวัดที่กักตัว_x',right_on='จังหวัด') #ทำการเชื่อมตาราง 2 ตาราง คือ data1 และ tv
Project ##เรียกดูตาราง
# Out:
#             date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0     2020-01-12                13,671                             86,534
# 1     2020-01-13                14,122                             81,181
# 2     2020-01-14                14,014                             82,506
# 3     2020-01-15                14,065                             83,364
# 4     2020-01-16                14,865                             83,492
# ...          ...                   ...                                ...
# 78633 2022-03-18                14,085                              8,004
# 78634 2022-03-18                14,085                              8,004
# 78635 2022-03-18                14,085                              8,004
# 78636 2022-03-18                14,085                              8,004
# 78637 2022-03-18                14,085                              8,004
#
#       ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                                67,815              29,869
# 1                                68,008              30,536
# 2                                63,819              30,177
# 3                                66,785              31,569
# 4                                65,458              33,014
# ...                                 ...                 ...
# 78633                             7,011              15,640
# 78634                             7,011              15,640
# 78635                             7,011              15,640
# 78636                             7,011              15,640
# 78637                             7,011              15,640
#
#       ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ  \
# 0                               26,776                          25,949
# 1                               26,862                          24,685
# 2                               25,744                          23,256
# 3                               26,960                          24,958
# 4                               27,474                          23,618
# ...                                ...                             ...
# 78633                              116                             117
# 78634                              116                             117
# 78635                              116                             117
# 78636                              116                             117
# 78637                              116                             117
#
#            No.    เพศ_x    เพศ_y จังหวัดที่กักตัว_x จังหวัดที่กักตัว_y  \
# 0          1.0     หญิง      1.0      กรุงเทพมหานคร                1.0
# 1            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 2            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 3            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 4            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# ...        ...      ...      ...                ...                ...
# 78633  27071.0  ไม่ระบุ   2088.0           เพชรบุรี              355.0
# 78634  27071.0  ไม่ระบุ   2088.0          เพชรบูรณ์              101.0
# 78635  27071.0  ไม่ระบุ   2088.0                เลย              139.0
# 78636  27071.0  ไม่ระบุ   2088.0               แพร่               73.0
# 78637  27071.0  ไม่ระบุ   2088.0         แม่ฮ่องสอน               34.0
#
#              จังหวัด             ภูมิภาค
# 0      กรุงเทพมหานคร                กลาง
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                NaN                 NaN
# ...              ...                 ...
# 78633       เพชรบุรี             ตะวันตก
# 78634      เพชรบูรณ์                กลาง
# 78635            เลย  ตะวันออกเฉียงเหนือ
# 78636           แพร่               เหนือ
# 78637     แม่ฮ่องสอน               เหนือ
#
# [78638 rows x 14 columns]

# %% [markdown]
# ### ดูค่า Missing

# %%
Project.isnull().any() ## ดูค่า Missing
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# No.                                   False
# เพศ_x                                 False
# เพศ_y                                 False
# จังหวัดที่กักตัว_x                    False
# จังหวัดที่กักตัว_y                    False
# จังหวัด                                True
# ภูมิภาค                                True
# dtype: bool

# %% [markdown]
# ###กำจัดค่า Missing

# %%
Project = Project.fillna('ไม่ระบุ') ##แทนค่า NaN เป็น ไม่ระบุ

# %%
Project
# Out:
#             date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0     2020-01-12                13,671                             86,534
# 1     2020-01-13                14,122                             81,181
# 2     2020-01-14                14,014                             82,506
# 3     2020-01-15                14,065                             83,364
# 4     2020-01-16                14,865                             83,492
# ...          ...                   ...                                ...
# 78633 2022-03-18                14,085                              8,004
# 78634 2022-03-18                14,085                              8,004
# 78635 2022-03-18                14,085                              8,004
# 78636 2022-03-18                14,085                              8,004
# 78637 2022-03-18                14,085                              8,004
#
#       ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                                67,815              29,869
# 1                                68,008              30,536
# 2                                63,819              30,177
# 3                                66,785              31,569
# 4                                65,458              33,014
# ...                                 ...                 ...
# 78633                             7,011              15,640
# 78634                             7,011              15,640
# 78635                             7,011              15,640
# 78636                             7,011              15,640
# 78637                             7,011              15,640
#
#       ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ  \
# 0                               26,776                          25,949
# 1                               26,862                          24,685
# 2                               25,744                          23,256
# 3                               26,960                          24,958
# 4                               27,474                          23,618
# ...                                ...                             ...
# 78633                              116                             117
# 78634                              116                             117
# 78635                              116                             117
# 78636                              116                             117
# 78637                              116                             117
#
#            No.    เพศ_x    เพศ_y จังหวัดที่กักตัว_x จังหวัดที่กักตัว_y  \
# 0          1.0     หญิง      1.0      กรุงเทพมหานคร                1.0
# 1            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 2            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 3            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 4            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# ...        ...      ...      ...                ...                ...
# 78633  27071.0  ไม่ระบุ   2088.0           เพชรบุรี              355.0
# 78634  27071.0  ไม่ระบุ   2088.0          เพชรบูรณ์              101.0
# 78635  27071.0  ไม่ระบุ   2088.0                เลย              139.0
# 78636  27071.0  ไม่ระบุ   2088.0               แพร่               73.0
# 78637  27071.0  ไม่ระบุ   2088.0         แม่ฮ่องสอน               34.0
#
#              จังหวัด             ภูมิภาค
# 0      กรุงเทพมหานคร                กลาง
# 1            ไม่ระบุ             ไม่ระบุ
# 2            ไม่ระบุ             ไม่ระบุ
# 3            ไม่ระบุ             ไม่ระบุ
# 4            ไม่ระบุ             ไม่ระบุ
# ...              ...                 ...
# 78633       เพชรบุรี             ตะวันตก
# 78634      เพชรบูรณ์                กลาง
# 78635            เลย  ตะวันออกเฉียงเหนือ
# 78636           แพร่               เหนือ
# 78637     แม่ฮ่องสอน               เหนือ
#
# [78638 rows x 14 columns]

# %%
Project.isnull().any() ## ดูค่า Missing
# Out:
# date                                  False
# ท่าอากาศยานสุวรรณภูมิ                 False
# ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ    False
# ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ     False
# ท่าอากาศยานดอนเมือง                   False
# ท่าอากาศยานดอนเมือง ขาเข้าประเทศ      False
# ท่าอากาศยานดอนเมือง ขาออกประเทศ       False
# No.                                   False
# เพศ_x                                 False
# เพศ_y                                 False
# จังหวัดที่กักตัว_x                    False
# จังหวัดที่กักตัว_y                    False
# จังหวัด                               False
# ภูมิภาค                               False
# dtype: bool

# %%
Project['year'] = Project['date'].dt.year ##สร้าง column 'year' ขึ้นมาเพื่อรับค่า ปี ของ 'announce_date'
Project['month'] = Project['date'].dt.month ##สร้าง column 'mont' ขึ้นมาเพื่อรับค่า เดือน ของ 'announce_date'

# %%
Project
# Out:
#             date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0     2020-01-12                13,671                             86,534
# 1     2020-01-13                14,122                             81,181
# 2     2020-01-14                14,014                             82,506
# 3     2020-01-15                14,065                             83,364
# 4     2020-01-16                14,865                             83,492
# ...          ...                   ...                                ...
# 78633 2022-03-18                14,085                              8,004
# 78634 2022-03-18                14,085                              8,004
# 78635 2022-03-18                14,085                              8,004
# 78636 2022-03-18                14,085                              8,004
# 78637 2022-03-18                14,085                              8,004
#
#       ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                                67,815              29,869
# 1                                68,008              30,536
# 2                                63,819              30,177
# 3                                66,785              31,569
# 4                                65,458              33,014
# ...                                 ...                 ...
# 78633                             7,011              15,640
# 78634                             7,011              15,640
# 78635                             7,011              15,640
# 78636                             7,011              15,640
# 78637                             7,011              15,640
#
#       ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ  \
# 0                               26,776                          25,949
# 1                               26,862                          24,685
# 2                               25,744                          23,256
# 3                               26,960                          24,958
# 4                               27,474                          23,618
# ...                                ...                             ...
# 78633                              116                             117
# 78634                              116                             117
# 78635                              116                             117
# 78636                              116                             117
# 78637                              116                             117
#
#            No.    เพศ_x    เพศ_y จังหวัดที่กักตัว_x จังหวัดที่กักตัว_y  \
# 0          1.0     หญิง      1.0      กรุงเทพมหานคร                1.0
# 1            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 2            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 3            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 4            0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# ...        ...      ...      ...                ...                ...
# 78633  27071.0  ไม่ระบุ   2088.0           เพชรบุรี              355.0
# 78634  27071.0  ไม่ระบุ   2088.0          เพชรบูรณ์              101.0
# 78635  27071.0  ไม่ระบุ   2088.0                เลย              139.0
# 78636  27071.0  ไม่ระบุ   2088.0               แพร่               73.0
# 78637  27071.0  ไม่ระบุ   2088.0         แม่ฮ่องสอน               34.0
#
#              จังหวัด             ภูมิภาค  year  month
# 0      กรุงเทพมหานคร                กลาง  2020      1
# 1            ไม่ระบุ             ไม่ระบุ  2020      1
# 2            ไม่ระบุ             ไม่ระบุ  2020      1
# 3            ไม่ระบุ             ไม่ระบุ  2020      1
# 4            ไม่ระบุ             ไม่ระบุ  2020      1
# ...              ...                 ...   ...    ...
# 78633       เพชรบุรี             ตะวันตก  2022      3
# 78634      เพชรบูรณ์                กลาง  2022      3
# 78635            เลย  ตะวันออกเฉียงเหนือ  2022      3
# 78636           แพร่               เหนือ  2022      3
# 78637     แม่ฮ่องสอน               เหนือ  2022      3
#
# [78638 rows x 16 columns]

# %% [markdown]
# #เลือกข้อมูลมาทำ Dashboard

# %%
Project_2021 = Project[(Project['year'] == 2020) | (Project['year'] == 2021)] ### เลือกข้อมูลที่มีค่า year เท่ากับ 2020 เก็บไว้ในตัวแปร Project_2020
Project_2021 ## เรียกดูตาราง
# Out:
#             date ท่าอากาศยานสุวรรณภูมิ ท่าอากาศยานสุวรรณภูมิ ขาเข้าประเทศ  \
# 0     2020-01-12                13,671                             86,534
# 1     2020-01-13                14,122                             81,181
# 2     2020-01-14                14,014                             82,506
# 3     2020-01-15                14,065                             83,364
# 4     2020-01-16                14,865                             83,492
# ...          ...                   ...                                ...
# 60885 2021-12-31                15,027                              6,495
# 60886 2021-12-31                15,027                              6,495
# 60887 2021-12-31                15,027                              6,495
# 60888 2021-12-31                15,027                              6,495
# 60889 2021-12-31                15,027                              6,495
#
#       ท่าอากาศยานสุวรรณภูมิ ขาออกประเทศ ท่าอากาศยานดอนเมือง  \
# 0                                67,815              29,869
# 1                                68,008              30,536
# 2                                63,819              30,177
# 3                                66,785              31,569
# 4                                65,458              33,014
# ...                                 ...                 ...
# 60885                             4,538              17,979
# 60886                             4,538              17,979
# 60887                             4,538              17,979
# 60888                             4,538              17,979
# 60889                             4,538              17,979
#
#       ท่าอากาศยานดอนเมือง ขาเข้าประเทศ ท่าอากาศยานดอนเมือง ขาออกประเทศ  \
# 0                               26,776                          25,949
# 1                               26,862                          24,685
# 2                               25,744                          23,256
# 3                               26,960                          24,958
# 4                               27,474                          23,618
# ...                                ...                             ...
# 60885                               24                              47
# 60886                               24                              47
# 60887                               24                              47
# 60888                               24                              47
# 60889                               24                              47
#
#           No.    เพศ_x    เพศ_y จังหวัดที่กักตัว_x จังหวัดที่กักตัว_y  \
# 0         1.0     หญิง      1.0      กรุงเทพมหานคร                1.0
# 1           0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 2           0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 3           0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# 4           0  ไม่ระบุ  ไม่ระบุ            ไม่ระบุ            ไม่ระบุ
# ...       ...      ...      ...                ...                ...
# 60885  3111.0  ไม่ระบุ    162.0           เพชรบุรี               17.0
# 60886  3111.0  ไม่ระบุ    162.0          เพชรบูรณ์               46.0
# 60887  3111.0  ไม่ระบุ    162.0                เลย                8.0
# 60888  3111.0  ไม่ระบุ    162.0               แพร่                2.0
# 60889  3111.0  ไม่ระบุ    162.0         แม่ฮ่องสอน               22.0
#
#              จังหวัด             ภูมิภาค  year  month
# 0      กรุงเทพมหานคร                กลาง  2020      1
# 1            ไม่ระบุ             ไม่ระบุ  2020      1
# 2            ไม่ระบุ             ไม่ระบุ  2020      1
# 3            ไม่ระบุ             ไม่ระบุ  2020      1
# 4            ไม่ระบุ             ไม่ระบุ  2020      1
# ...              ...                 ...   ...    ...
# 60885       เพชรบุรี             ตะวันตก  2021     12
# 60886      เพชรบูรณ์                กลาง  2021     12
# 60887            เลย  ตะวันออกเฉียงเหนือ  2021     12
# 60888           แพร่               เหนือ  2021     12
# 60889     แม่ฮ่องสอน               เหนือ  2021     12
#
# [60890 rows x 16 columns]

# %%
Project_2021.to_csv('Project_20_21.csv', encoding = 'utf-8') ##บันทึก Project_2020 เป็นไฟล์ .csv
