# %% [markdown]
# <a href="https://colab.research.google.com/github/Benza1611/data_viz_2022/blob/main/DataViz02_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Scatter Plot

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter([1,-1],[2,-1])

# %%
plt.scatter(df['PetalLength'],df['SepalLength'])

# %% [markdown]
# ## เปลี่ยนสี

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='r')

# %% [markdown]
# ## ระบุสีให้แต่ละจุด

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# ### แทนค่าชื่อดอกไม้ด้วยตัวอักษรแทนสี (r g b c m y k w)

# %%
df2 = df.replace({'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'})

# %%
df2.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0          5.1         3.5          1.4         0.2    r
# 1          4.9         3.0          1.4         0.2    r
# 2          4.7         3.2          1.3         0.2    r
# 3          4.6         3.1          1.5         0.2    r
# 4          5.0         3.6          1.4         0.2    r

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c=df2['Name'])

# %% [markdown]
# ## เพิ่มรายละเอียดกราฟ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c=df2['Name']) #วาดกราฟ
plt.xlabel('PetalLength') #ชื่อแกนX
plt.ylabel('SepalLength') #ชื่อแกนy
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อ marker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa') #วาดกราฟ
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor') #วาดกราฟ
plt.scatter(df2['PetalLength'][100:150],df2['SepalLength'][100:150],c=df2['Name'][100:150],label='verginiga') #วาดกราฟ
plt.legend() #อธิบาย marker
plt.xlabel('PetalLength') #ชื่อแกนX
plt.ylabel('SepalLength') #ชื่อแกนy
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อกราฟ

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa') #วาดกราฟ
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor') #วาดกราฟ
plt.scatter(df2['PetalLength'][100:150],df2['SepalLength'][100:150],c=df2['Name'][100:150],label='verginiga') #วาดกราฟ
plt.legend() #อธิบาย marker
plt.xlabel('PetalLength') #ชื่อแกนX
plt.ylabel('SepalLength') #ชื่อแกนy
plt.title('comparing petal&sepal length of different iris flowers'); #ชื่อกราฟ

# %% [markdown]
# ### ใช้ขนาดของ marker ในการแสดงค่าใน column

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50]) #วาดกราฟ
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100]) #วาดกราฟ
plt.scatter(df2['PetalLength'][100:150],df2['SepalLength'][100:150],c=df2['Name'][100:150],label='verginiga',s=df2['PetalWidth'][100:150]) #วาดกราฟ
plt.legend() #อธิบาย marker
plt.xlabel('PetalLength') #ชื่อแกนX
plt.ylabel('SepalLength') #ชื่อแกนy
plt.title('comparing petal&sepal length of different iris flowers'); #ชื่อกราฟ

# %% [markdown]
# ### ขยายขนาด marker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=20*df2['PetalWidth'][:50]) #วาดกราฟ
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=20*df2['PetalWidth'][50:100]) #วาดกราฟ
plt.scatter(df2['PetalLength'][100:150],df2['SepalLength'][100:150],c=df2['Name'][100:150],label='verginiga',s=20*df2['PetalWidth'][100:150]) #วาดกราฟ
plt.legend() #อธิบาย marker
plt.xlabel('PetalLength') #ชื่อแกนX
plt.ylabel('SepalLength') #ชื่อแกนy
plt.title('comparing petal&sepal length of different iris flowers'); #ชื่อกราฟ

# %% [markdown]
# ### ปรับความโปรงใส่ของ marker เพื่อให้มองเห็นจุดที่ถูกบัง (Buble Chart)

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=20*df2['PetalWidth'][:50]) #วาดกราฟ
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=20*df2['PetalWidth'][50:100]) #วาดกราฟ
plt.scatter(df2['PetalLength'][100:150],df2['SepalLength'][100:150],alpha=0.5,c=df2['Name'][100:150],label='verginiga',s=20*df2['PetalWidth'][100:150]) #วาดกราฟ
plt.legend() #อธิบาย marker
plt.xlabel('PetalLength') #ชื่อแกนX
plt.ylabel('SepalLength') #ชื่อแกนy
plt.title('comparing petal&sepal length of different iris flowers'); #ชื่อกราฟ

# %% [markdown]
# ### เปลี่ยนหน้าตาของ marker เพื่อความสวยงาม

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=20*df2['PetalWidth'][:50],marker='$S$') #วาดกราฟ
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=20*df2['PetalWidth'][50:100],marker='X') #วาดกราฟ
plt.scatter(df2['PetalLength'][100:150],df2['SepalLength'][100:150],alpha=0.5,c=df2['Name'][100:150],label='verginiga',s=20*df2['PetalWidth'][100:150],marker='^') #วาดกราฟ
plt.legend() #อธิบาย marker
plt.xlabel('PetalLength') #ชื่อแกนX
plt.ylabel('SepalLength') #ชื่อแกนy
plt.title('comparing petal&sepal length of different iris flowers'); #ชื่อกราฟ

# %% [markdown]
# ### แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection="3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'],s=80*df2['PetalWidth'])

# %%
ax = plt.axes(projection="3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='setosa')
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],s=80*df2['PetalWidth'][50:100],label='versicolor')
ax.scatter(df2['PetalLength'][100:150],df2['SepalLength'][100:150],c=df2['Name'][100:150],s=80*df2['PetalWidth'][100:150],label='verginiga')
plt.legend() #อธิบาย marker
plt.xlabel('PetalLength') #ชื่อแกนX
plt.ylabel('SepalLength') #ชื่อแกนy
plt.title('comparing petal&sepal length of different iris flowers'); #ชื่อกราฟ

# %% [markdown]
# # Boxplot

# %% [markdown]
# ![1*2c21SkzJMf3frPXPAR_gZA-2.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df['SepalLength'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f948b52d350>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f948b0503d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f948b058410>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f948b050e90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f948b52d910>,
#   <matplotlib.lines.Line2D at 0x7f948b52de50>]}

# %%
plt.boxplot(df['SepalLength'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f948afb1ed0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f948afb9f50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f948afc2f90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f948afc2a50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f948afb94d0>,
#   <matplotlib.lines.Line2D at 0x7f948afb9a10>]}

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False)

# %% [markdown]
# median

# %%
ybp['medians'][0].get_ydata()
# Out:
# array([0.925, 1.075])

# %%
ybp['medians'][0].get_xdata()
# Out:
# array([5.8, 5.8])

# %%
ybp['whiskers'][0].get_xdata()
# Out:
# array([5.1, 4.3])

# %% [markdown]
# min

# %%
min(ybp['whiskers'][0].get_xdata())
# Out:
# 4.3

# %% [markdown]
# mix

# %%
max(ybp['whiskers'][1].get_xdata())
# Out:
# 7.9

# %%
ybp['caps'][1].get_xdata()
# Out:
# array([7.9, 7.9])

# %% [markdown]
# q1

# %%
ybp['boxes'][0].get_xdata()
# Out:
# array([5.1, 5.1, 6.4, 6.4, 5.1])

# %%
ybp['boxes'][0].get_xdata()[0]
# Out:
# 5.1

# %%
max(ybp['whiskers'][0].get_xdata())
# Out:
# 5.1

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f948b099290>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f948b166a50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f948b1bdc10>],
#  'means': [<matplotlib.lines.Line2D at 0x7f948b1bd490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f948af6c410>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f948b165d50>,
#   <matplotlib.lines.Line2D at 0x7f948b080550>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline=True,showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f948b24f610>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f948b28f6d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f948b29e390>],
#  'means': [<matplotlib.lines.Line2D at 0x7f948b29e0d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f948b28f390>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f948b24fc10>,
#   <matplotlib.lines.Line2D at 0x7f948b24f950>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanprops={'marker':'o'})
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f948b2bd2d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f948da00c10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f948b482950>],
#  'means': [<matplotlib.lines.Line2D at 0x7f948d8a9b10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f948d8a9910>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f948b2bd4d0>,
#   <matplotlib.lines.Line2D at 0x7f948b2bdf10>]}

# %% [markdown]
# # Quiz กลุ่มfinal
#
# 1. เขียน function ที่รับ input เป็น output ของ boxplot แล้ว แสดงค่า min, max, q1, q2, q3
# 2. วาด boxplot เปรียบเทียบ การกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3 ชนิด
